# %% [markdown]
# # Filtering museum objects
#
# We only want certain kinds of items from the Harvard Art Museums that fit well with our application. For example, the Art Museums seem to have a large collection of images of coins, and those don't really fit well with CLIP, so we filter them out in this step.
#
# Other objects have no images, which make them not useful. Let's explore what these images look like!

# %%
import json

with open("../data/artmuseums.json", "r") as f:
    dataset = json.load(f)

# %%
len(dataset)
# Out:
# 236120

# %%
dataset[0]
# Out:
# {'copyright': None,
#  'contextualtextcount': 0,
#  'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#  'accesslevel': 1,
#  'dateoflastpageview': '2020-11-25',
#  'classificationid': 50,
#  'division': 'Asian and Mediterranean Art',
#  'markscount': 0,
#  'publicationcount': 0,
#  'totaluniquepageviews': 7,
#  'contact': 'am_asianmediterranean@harvard.edu',
#  'colorcount': 4,
#  'rank': 1003,
#  'details': {'coins': {'reverseinscription': None,
#    'dieaxis': '8',
#    'metal': 'AR',
#    'obverseinscription': None,
#    'denomination': 'litra',
#    'dateonobject': None}},
#  'state': None,
#  'id': 189263,
#  'verificationleveldescription': 'Good. Object is well described and information is vetted',
#  'period': 'Classical period, Early',
#  'images': [{'date': '2004-06-03',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 38027,
#    'idsid': 18778012,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': 'COIN00538',
#    'displayorder': 1,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN00538_dynmc',
#    'alttext': None,
#    'width': 1024,
#    'publiccaption': None,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18778012',
#    'height': 478}],
#  'worktypes': [{'worktypeid': '103', 'worktype': 'coin'}],
#  'imagecount': 1,
#  'totalpageviews': 7,
#  'accessionyear': None,
#  'standardreferencenumber': None,
#  'signed': None,
#  'classification': 'Coins',
#  'relatedcount': 0,
#  'verificationlevel': 3,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN00538_dynmc',
#  'titlescount': 1,
#  'peoplecount': 0,
#  'style': None,
#  'lastupdate': '2022-10-29T05:27:40-0400',
#  'commentary': None,
#  'periodid': 906,
#  'technique': 'Struck',
#  'edition': None,
#  'description': "Obv.: Lion's head facing; Rev.: RECI in laurel wreath",
#  'medium': 'Silver',
#  'lendingpermissionlevel': 0,
#  'title': 'Litra of Rhegion',
#  'accessionmethod': None,
#  'colors': [{'color': '#000000',
#    'spectrum': '#1eb264',
#    'hue': 'Black',
#    'percent': 0.9365714285714286,
#    'css3': '#000000'},
#   {'color': '#4b3232',
#    'spectrum': '#4ab851',
#    'hue': 'Red',
#    'percent': 0.06190476190476191,
#    'css3': '#2f4f4f'},
#   {'color': '#190000',
#    'spectrum': '#2eb45d',
#    'hue': 'Black',
#    'percent': 0.0008571428571428571,
#    'css3': '#000000'},
#   {'color': '#000019',
#    'spectrum': '#1eb264',
#    'hue': 'Black',
#    'percent': 0.0006666666666666666,
#    'css3': '#000000'}],
#  'provenance': 'Acq. Ravel, 1929',
#  'groupcount': 0,
#  'dated': 'c. 450 BCE',
#  'department': 'Department of Ancient and Byzantine Art & Numismatics',
#  'dateend': -445,
#  'url': 'https://www.harvardartmuseums.org/collections/object/189263',
#  'dateoffirstpageview': '2014-10-17',
#  'century': '5th century BCE',
#  'objectnumber': '1.1965.534',
#  'labeltext': None,
#  'datebegin': -455,
#  'culture': 'Greek',
#  'exhibitioncount': 0,
#  'imagepermissionlevel': 0,
#  'mediacount': 0,
#  'objectid': 189263,
#  'techniqueid': 7320,
#  'dimensions': '0.71 g',
#  'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/189263',
#    'type': 'IIIF Manifest',
#    'format': 'application/json',
#    'profile': 'http://iiif.io/api/presentation/2/context.json'}]}

# %%
sum(["primaryimageurl" not in item for item in dataset])
# Out:
# 22994

# %%
len(set([item["primaryimageurl"] for item in dataset if "primaryimageurl" in item]))
# Out:
# 210681

# %%
210681 + 22994
# Out:
# 233675

# %%
len(dataset)
# Out:
# 236120

# %% [markdown]
# Okay, it looks like about 10% of the items in the dataset don't have any image associated with them. Furthermore, there are 3000 image URLs that are duplicated. Let's look at some of these duplicates.

# %%
from collections import Counter

Counter([item["primaryimageurl"] for item in dataset if "primaryimageurl" in item]).most_common(40)
# Out:
# [('https://nrs.harvard.edu/urn-3:HUAM:INV180154_dynmc', 48),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180030_dynmc', 38),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180019_dynmc', 36),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180031_dynmc', 34),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180197_dynmc', 32),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180165_dynmc', 28),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180032_dynmc', 27),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186007_dynmc', 26),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180113_dynmc', 25),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180100_dynmc', 25),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180157_dynmc', 23),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV179871_dynmc', 23),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180153_dynmc', 23),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS35829_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV141481_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180155_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180241_dynmc', 22),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186005_dynmc', 21),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV185977_dynmc', 21),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180107_dynmc', 20),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180028_dynmc', 20),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186185_dynmc', 20),
#  ('https://nrs.harvard.edu/urn-3:HUAM:767370', 19),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180027_dynmc', 19),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186193_dynmc', 17),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180068_dynmc', 17),
#  ('https://nrs.harvard.edu/urn-3:HUAM:CARP12130_dynmc', 16),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180029_dynmc', 16),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV185670_dynmc', 16),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS33642_dynmc', 15),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV140426_dynmc', 15),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV186180_dynmc', 14),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180112_dynmc', 14),
#  ('https://nrs.harvard.edu/urn-3:HUAM:VRS31249_dynmc', 12),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV179869_dynmc', 12),
#  ('https://nrs.harvard.edu/urn-3:HUAM:CARP12081_dynmc', 11),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV179867_dynmc', 11),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV180000_dynmc', 10),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV203770_dynmc', 10),
#  ('https://nrs.harvard.edu/urn-3:HUAM:INV203772_dynmc', 10)]

# %%
[item["dimensions"] for item in dataset[0:50] + dataset[10000:10050]]
# Out:
# ['0.71 g',
#  '16.82 g',
#  '17.33 g',
#  '7.94 g',
#  '7.63 g',
#  '7.67 g',
#  '7.49 g',
#  '7.54 g',
#  '2.35 g',
#  '2.47 g',
#  '1.06 g',
#  '0.5 g',
#  '0.7 g',
#  '0.89 g',
#  '8.43 g',
#  '8.62 g',
#  '8.47 g',
#  '8.92 g',
#  '8.7 g',
#  '8.73 g',
#  '8.43 g',
#  '17.27 g',
#  '8.44 g',
#  '0.6 g',
#  '4.79 g',
#  '17.19 g',
#  '17.17 g',
#  '16.65 g',
#  '16.69 g',
#  '17.08 g',
#  '16.77 g',
#  '1.88 g',
#  '2.1 g',
#  '2.13 g',
#  '1.34 g',
#  '1.35 g',
#  '1.34 g',
#  '21.37 g',
#  '1.46 g',
#  '3.36 g',
#  '0.7 g',
#  '0.71 g',
#  '0.69 g',
#  '17.12 g',
#  '8.03 g',
#  '0.43 g',
#  '16.32 g',
#  '17.33 g',
#  '16.93 g',
#  '16.81 g',
#  'image: 27.9 x 21.6 cm (11 x 8 1/2 in.)',
#  'image: 15.1 x 8.9 cm (5 15/16 x 3 1/2 in.)',
#  'image: 28.2 x 21.6 cm (11 1/8 x 8 1/2 in.)',
#  'image: 29.1 x 21.7 cm (11 7/16 x 8 9/16 in.)',
#  'image: 27.8 x 21.5 cm (10 15/16 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28.2 x 21.6 cm (11 1/8 x 8 1/2 in.)',
#  'image: 28.2 x 21.6 cm (11 1/8 x 8 1/2 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28.1 x 21.5 cm (11 1/16 x 8 7/16 in.)',
#  'image: 28.2 x 21.5 cm (11 1/8 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28.1 x 21.5 cm (11 1/16 x 8 7/16 in.)',
#  'image: 28.2 x 21.5 cm (11 1/8 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28.1 x 21.5 cm (11 1/16 x 8 7/16 in.)',
#  'image: 28.2 x 21.5 cm (11 1/8 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28.1 x 21.5 cm (11 1/16 x 8 7/16 in.)',
#  'image: 28.2 x 21.5 cm (11 1/8 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28.1 x 21.5 cm (11 1/16 x 8 7/16 in.)',
#  'image: 28.2 x 21.5 cm (11 1/8 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 14.5 x 8 cm (5 11/16 x 3 1/8 in.)',
#  'image: 16 x 8 cm (6 5/16 x 3 1/8 in.)',
#  'image: 16 x 8 cm (6 5/16 x 3 1/8 in.)',
#  'image: 16 x 8 cm (6 5/16 x 3 1/8 in.)',
#  'image: 16 x 8 cm (6 5/16 x 3 1/8 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28 x 21.5 cm (11 x 8 7/16 in.)',
#  'image: 28 x 21.5 cm (11 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28 x 21.5 cm (11 x 8 7/16 in.)',
#  'image: 28 x 21.5 cm (11 x 8 7/16 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 28 x 21.5 cm (11 x 8 7/16 in.)',
#  'image: 23 x 14 cm (9 1/16 x 5 1/2 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 8.8 x 14 cm (3 7/16 x 5 1/2 in.)',
#  'image: 8.8 x 14 cm (3 7/16 x 5 1/2 in.)',
#  'image: 8.8 x 14 cm (3 7/16 x 5 1/2 in.)',
#  'image: 8.8 x 14 cm (3 7/16 x 5 1/2 in.)',
#  'image: 8.8 x 14 cm (3 7/16 x 5 1/2 in.)',
#  'mount: 35.5 x 56 cm (14 x 22 1/16 in.)',
#  'image: 8.8 x 12.5 cm (3 7/16 x 4 15/16 in.)',
#  'image: 8.8 x 12.5 cm (3 7/16 x 4 15/16 in.)',
#  'image: 8.8 x 12.5 cm (3 7/16 x 4 15/16 in.)',
#  'image: 8.8 x 12.5 cm (3 7/16 x 4 15/16 in.)',
#  'image: 8.8 x 12.5 cm (3 7/16 x 4 15/16 in.)']

# %% [markdown]
# Okay, looks like all of the coins have dimensions in grams. The weird print also has a `None` dimension. Maybe for now I'll just filter for all items that have an image and some 2D dimensions.

# %%
dim_type = Counter()
for item in dataset:
    kind = None
    dims = item["dimensions"]
    if isinstance(dims, str):
        idx = dims.find(":")
        if idx != -1:
            kind = dims[:idx]
        elif dims.endswith("g"):
            kind = "weight grams"
        elif " cm" in dims:
            kind = "other cm"
        else:
            kind = dims
    dim_type[kind] += 1

dim_type
# Out:
# Counter({'weight grams': 17437,
#          'other cm': 83909,
#          'sheet': 6767,
#          '33.3 × 69.5 cm (13 1/8 × 27 3/8 in.)\r\nframe': 1,
#          None: 53404,
#          'actual': 5560,
#          '19.3 x 22.8 cm (7 5/8 x 9 in.)\r\nmount': 1,
#          'overall for matted triptych': 28,
#          'Paper': 1758,
#          'image': 34804,
#          '22.6 x 47 cm (8 7/8 x 18 1/2 in.)\r\nmount': 1,
#          '22.8 x 48 cm (9 x 18 7/8 in.)\r\nsheet': 1,
#          '22.1 x 47.8 cm (8 11/16 x 18 13/16 in.)\r\nmount': 1,
#          '56 x 47.8 cm (22 1/16 x 18 13/16 in.)\r\nmount': 1,
#          '22.6 x 46.9 cm (8 7/8 x 18 7/16 in.)\r\nmount': 1,
#          '22.5 x 47.6 cm (8 7/8 x 18 3/4 in.)\r\nsheet': 1,
#          '40.6 x 58.5 cm (16 x 23 1/16 in.)\r\nmount': 1,
#          '59.2 x 39.3 cm (23 5/16 x 15 1/2 in.)\r\nmount': 1,
#          '59.6 x 42.1 cm (23 7/16 x 16 9/16 in.)\r\nmount': 1,
#          '40.7 x 59.9 cm (16 x 23 9/16 in.)\r\nmount': 1,
#          '36 x 47.2 cm (14 3/16 x 18 9/16 in.)\r\nmount': 1,
#          '40.6 x 59.4 cm (16 x 23 3/8 in.)\r\nmount': 1,
#          '36.5 x 46.8 cm (14 3/8 x 18 7/16 in.)\r\nmount': 1,
#          '22.3 x 47.8 cm (8 3/4 x 18 13/16 in.)\r\nmount': 1,
#          '22.5 x 47.9 cm (8 7/8 x 18 7/8 in.)\r\nmount': 1,
#          '22.5 x 47.5 cm (8 7/8 x 18 11/16 in.)\r\nmount': 1,
#          '47.4 x 39.6 cm (18 11/16 x 15 9/16 in.)\r\nmount': 1,
#          'greatest dimen.': 108,
#          'book closed': 4,
#          '21.59 x 16.51 cm (8 1/2 x 6 1/2 in.)\r\nframed': 1,
#          'fimage': 1,
#          '96.5 x 72.4 cm (38 x 28 1/2 in.)\r\nframed': 1,
#          '23 x 17 cm (9 1/16 x 6 11/16 in.)\r\nframed': 1,
#          '26.3 × 22.1 cm (10 3/8 × 8 11/16 in.)\r\nmount, including strip at bottom': 1,
#          'irregular': 1021,
#          '22.2 x 29.8 cm (8 3/4 x 11 3/4 in.)\r\nsheet': 1,
#          '35.1 x 47.5 cm (13 13/16 x 18 11/16 in.)\r\nmount': 1,
#          '43.2 x 54.8 cm (17 x 21 9/16 in.)\r\nmount': 2,
#          'each postcard': 1,
#          '18.9 x 34.5 cm (7 7/16 x 13 9/16 in.)\r\nsheet': 1,
#          '22 x 32.5 cm (8 11/16 x 12 13/16 in.)\r\nsheet': 4,
#          '47.5 x 54.1 cm (18 11/16 x 21 5/16 in.)\r\nmount': 1,
#          '43.2 x 53.3 cm (17 x 21 in.)\r\nmount': 2,
#          '21.3 x 30.3 cm (8 3/8 x 11 15/16 in.)\r\nsheet': 1,
#          '38.2 x 53.8 cm (15 1/16 x 21 3/16 in.)\r\nmount': 1,
#          '42.8 x 54 cm (16 7/8 x 21 1/4 in.)\r\nsheet': 1,
#          '44.1 x 54 cm (17 3/8 x 21 1/4 in.)\r\nmount': 1,
#          '43.8 x 54 cm (17 1/4 x 21 1/4 in.)\r\nmount': 1,
#          '42.2 x 56.5 cm (16 5/8 x 22 1/4 in.)\r\nmount': 1,
#          '44.2 x 54 cm (17 3/8 x 21 1/4 in.)\r\nmount': 1,
#          '53.8 x 43.1 cm (21 3/16 x 16 15/16 in.)\r\nmount': 1,
#          '43.5 x 54.1 cm (17 1/8 x 21 5/16 in.)\r\nmount': 1,
#          'mount': 2578,
#          '17.5 x 24 cm (6 7/8 x 9 7/16 in.)\r\nsheet': 1,
#          'visible': 1,
#          'sight': 3176,
#          '16.8 x 25 cm (6 5/8 x 9 13/16 in.)\r\nsheet': 1,
#          'mount ': 1,
#          '11.9 x 18.2 cm (4 11/16 x 7 3/16 in.)\r\nmount': 1,
#          '13.8 x 17.2 cm (5 7/16 x 6 3/4 in.)\r\nimage': 1,
#          '57 x 43.2 cm (22 7/16 x 17 in.)\r\nsheet': 1,
#          '24.2 x 18.8 cm (9 1/2 x 7 3/8 in.)\r\nsheet': 1,
#          '29 x 43 cm (11 7/16 x 16 15/16 in.)\r\nsheet': 1,
#          'oval': 14,
#          '12.4 x 19 cm (4 7/8 x 7 1/2 in.)\r\nmount': 1,
#          '15.1 x 20.3 cm (5 15/16 x 8 in.)\r\nmount': 1,
#          'each image': 185,
#          'plate': 5525,
#          '41 x 30 cm (16 1/8 x 11 13/16 in.)\r\nframed': 1,
#          '12.1 x 17 cm (4 3/4 x 6 11/16 in.)\r\nmount': 1,
#          '12.1 x 16.1 cm (4 3/4 x 6 5/16 in.)\r\nmount': 2,
#          '56 x 71.5 cm (22 1/16 x 28 1/8 in.)\r\nmount': 1,
#          'mount; actual': 5,
#          'block': 824,
#          '50.8 × 41 cm (20 × 16 1/8 in.)\r\nframe': 1,
#          '43 × 60 cm (16 15/16 × 23 5/8 in.)\r\nframed': 1,
#          '18.9 × 17.1 cm (7 7/16 × 6 3/4 in.)\r\nmount': 1,
#          'shark': 1,
#          'album': 1,
#          'folded sheet': 128,
#          'horizontal images': 17,
#          'images': 7,
#          'horizontal image': 23,
#          'lareger image': 1,
#          'vertical image': 17,
#          'vertical images': 17,
#          'left image': 5,
#          'top image': 2,
#          'large images': 1,
#          'each strip': 1,
#          'strip': 1,
#          'top images': 1,
#          'UL, UR and LL images': 1,
#          'larger image': 1,
#          'larger images': 1,
#          'overall': 56,
#          'book': 4,
#          '41 × 64 cm (16 1/8 × 25 3/16 in.)\r\nFrame': 1,
#          'assembled height': 1,
#          'design': 795,
#          'sheet; actual': 1038,
#          '21.4 x 16.4 cm (8 7/16 x 6 7/16 in.)\r\nglass plate': 1,
#          '36.4 x 45.2 cm (14 5/16 x 17 13/16 in.)\r\nmount': 1,
#          '12.2 x 19.2 cm (4 13/16 x 7 9/16 in.)\r\nimage': 1,
#          '10.8 x 16.1 cm (4 1/4 x 6 5/16 in.)\r\nSheet of cream wove paper adhered to left side of main support': 1,
#          '77.6 x 92.9 cm (30 9/16 x 36 9/16 in.)\r\nframe': 1,
#          '33.3 × 26.6 cm (13 1/8 × 10 1/2 in.)\r\nboard': 1,
#          '19.7 × 31.2 cm (7 3/4 × 12 5/16 in.)\r\nmount': 1,
#          'framed': 79,
#          '19.6 × 31.1 cm (7 11/16 × 12 1/4 in.)\r\nwith modern margins': 1,
#          '6.9 x 6.6 cm (2 11/16 x 2 5/8 in.)\r\nmount': 1,
#          '23.7 x 18.8 cm (9 5/16 x 7 3/8 in.)\r\nframed': 1,
#          '60 x 45.3 cm (23 5/8 x 17 13/16 in.)\r\nmount': 1,
#          '45.6 x 60.9 cm (17 15/16 x 24 in.)\r\nmount': 1,
#          '45.1 x 60.1 cm (17 3/4 x 23 11/16 in.)\r\nmount': 1,
#          '57.6 x 45 cm (22 11/16 x 17 11/16 in.)\r\nmount': 1,
#          '12 x 18.5 cm (4 3/4 x 7 5/16 in.)\r\nimage (oval)': 1,
#          '19 x 25 cm (7 1/2 x 9 13/16 in.)\r\nmount': 1,
#          'sheet and image': 11,
#          'image and sheet': 11,
#          'chine collé': 150,
#          'H': 39,
#          '47.8 x 37.5 cm (18 13/16 x 14 3/4 in.)\r\nsheet': 1,
#          '38.2 x 28.4 cm (15 1/16 x 11 3/16 in.)\r\nplate': 1,
#          '32 x 34.6 cm (12 5/8 x 13 5/8 in.)\r\nmount': 1,
#          'with cover': 31,
#          'stone': 66,
#          'with base': 9,
#          '38.1 x 28 cm (15 x 11 in.)\r\nBorder drawn around image.': 1,
#          '18 x 13 cm (7 1/16 x 5 1/8 in.)\r\nBorder drawn around image': 1,
#          'woodblock': 1,
#          'H. 55 x W. 62 x D. 24 cm (21 5/8 x 24 7/16 x 9 7/16 in.)\r\ncrate': 1,
#          '12.8 x 16.8 cm (5 1/16 x 6 5/8 in.)\r\nsheet': 1,
#          '50.8 x 63 cm (20 x 24 13/16 in.)\r\nsheet': 1,
#          '26.5 x 26.7 cm (10 7/16 x 10 1/2 in.)\r\nsheet': 1,
#          '28.3 x 22.1 cm (11 1/8 x 8 11/16 in.)\r\nmount': 1,
#          '25.8 x 32.3 cm (10 3/16 x 12 11/16 in.)\r\nsheet': 1,
#          '43.5 x 34.5 cm (17 1/8 x 13 9/16 in.)\r\nframed': 1,
#          '86.9 x 75.2 cm (34 3/16 x 29 5/8 in.)\r\nframed': 1,
#          'cover': 192,
#          '22.3 x 15 x 1 cm (8 3/4 x 5 7/8 x 3/8 in.)\r\nopen (H x W x D)': 1,
#          '13.4 cm (5 1/4 in.)\r\nElbow to wing': 1,
#          'max. with handle': 1,
#          'folio': 301,
#          'image with border': 176,
#          'Image': 2118,
#          'Sheet': 326,
#          '25.2 x 37.9 cm (9 15/16 x 14 15/16 in.)\r\nBorder drawn in brown ink': 1,
#          '18.9 x 22.8 cm (7 7/16 x 9 in.)\r\nmount': 1,
#          '71.6 x 57.8 cm (28 3/16 x 22 3/4 in.)\r\nframed': 1,
#          '9.5 x 12.7 cm (3 3/4 x 5 in.)\r\nsheet': 1,
#          'diam. (sight)': 3,
#          'H. 58 x W. 56 x D. 23 cm (22 13/16 x 22 1/16 x 9 1/16 in.)\r\ncrate': 1,
#          'max. with base': 1,
#          'painting max.': 2,
#          'without base': 12,
#          '31.4 x 12.7 x 12.7 cm (12 3/8 x 5 x 5 in.)\r\n(weight': 1,
#          '31.75 x 40.64 cm (12 1/2 x 16 in.)\r\nframed': 1,
#          'closed': 40,
#          '122.2 x 152.4 cm (48 1/8 x 60 in.)\r\nframe': 1,
#          'each print': 8,
#          '11.8 x 32.1 x 27.6 cm (4 5/8 x 12 5/8 x 10 7/8 in.)\r\nunspecified': 1,
#          'Overall': 241,
#          'H. 3.6  W. 3.3  Th. 0.3-0.5  \r\n': 1,
#          'H.  4.2 W. 4.2  Th. 0.3-0.4': 1,
#          'H. 2.2  W. 4.8  Th. 0.3-0.5': 1,
#          'joined to F': 1,
#          'cup and saucer combined': 1,
#          '50.8 × 113.7 cm (20 × 44 3/4 in.)\r\nframed': 1,
#          '25.4 x 45.7 cm (10 x 18 in.)\r\nframed': 2,
#          '27.3 x 46.4 cm (10 3/4 x 18 1/4 in.)\r\nframed': 1,
#          '35.5 x 60.9 cm (14 x 24 in.)\r\nframed': 1,
#          '36.8 × 50.8 cm (14 1/2 × 20 in.)\r\nframed': 1,
#          '43.2 x 71.1 cm (17 x 28 in.)\r\nframed': 1,
#          '73.03 x 138.75 cm (28 3/4 x 54 5/8 in.)\r\nframed': 1,
#          '6.9 x 8.2 cm (2 11/16 x 3 1/4 in.)\r\nmount': 1,
#          '13.4 x 18 cm (5 1/4 x 7 1/16 in.)\r\nmount': 1,
#          '13.3 x 17.7 cm (5 1/4 x 6 15/16 in.)\r\nmount': 1,
#          '16 x 16.2 cm (6 5/16 x 6 3/8 in.)\r\nmount': 1,
#          '20.1 x 12.8 cm (7 15/16 x 5 1/16 in.)\r\nmount': 1,
#          '8.5 x 12.5 cm (3 3/8 x 4 15/16 in.)\r\nmount': 1,
#          '7.1 × 6.5 cm (2 13/16 × 2 9/16 in.)\r\nmount': 1,
#          '31.6 x 23.3 cm (12 7/16 x 9 3/16 in.)\r\nmount': 1,
#          '12.2 x 18.6 cm (4 13/16 x 7 5/16 in.)\r\nmount': 1,
#          'man': 1,
#          '45.5 x 48.8 cm (17 15/16 x 19 3/16 in.)\r\ncanvas': 1,
#          '48.2 x 63.5 cm (19 x 25 in.)\r\ncanvas': 1,
#          '41.9 x 64.8 cm (16 1/2 x 25 1/2 in.)\r\nframed': 1,
#          '51.8 x 72.2 cm (20 3/8 x 28 7/16 in.)\r\nframed': 1,
#          '30.8 x 42.1 cm (12 1/8 x 16 9/16 in.)\r\nimage': 1,
#          '27.3 x 23.9 cm (10 3/4 x 9 7/16 in.)\r\nmount': 1,
#          '43.1 x 54 x 9.5 cm (16 15/16 x 21 1/4 x 3 3/4 in.)\r\nwith mount': 1,
#          '16.9 x 25.1 cm (6 5/8 x 9 7/8 in.)\r\nmount': 1,
#          'diam.': 20,
#          '17.3 x 21 cm (6 13/16 x 8 1/4 in.)\r\nimage': 1,
#          '27.3 x 36 cm (10 3/4 x 14 3/16 in.)\r\nimage': 1,
#          '32 x 26 cm (12 5/8 x 10 1/4 in.)\r\nmount': 1,
#          '27.3 x 22.6 cm (10 3/4 x 8 7/8 in.)\r\nmount': 1,
#          '27.8 x 27.7 cm (10 15/16 x 10 7/8 in.)\r\nmount': 1,
#          '35.5 x 45.7 cm (14 x 18 in.)\r\nimage, in lunette shape': 1,
#          '14.8 x 19.6 cm (5 13/16 x 7 11/16 in.)\r\nimage': 1,
#          '24.1 x 31.9 cm (9 1/2 x 12 9/16 in.)\r\nmount': 1,
#          '15.7 x 12.9 cm (6 3/16 x 5 1/16 in.)\r\nimage': 1,
#          '14.3 x 17.5 cm (5 5/8 x 6 7/8 in.)\r\nimage': 1,
#          '15.7 x 28.9 cm (6 3/16 x 11 3/8 in.)\r\nimage': 1,
#          '26.8 x 35 cm (10 9/16 x 13 3/4 in.)\r\nimage': 1,
#          '18.6 x 24.4 cm (7 5/16 x 9 5/8 in.)\r\nmount': 1,
#          '29.1 x 20.1 cm (11 7/16 x 7 15/16 in.)\r\nmount': 1,
#          '18.6 x 24.5 cm (7 5/16 x 9 5/8 in.)\r\nmount': 1,
#          '20.9 x 27.9 cm (8 1/4 x 11 in.)\r\nmount': 1,
#          'front': 1,
#          '119 x 93.2 cm (46 7/8 x 36 11/16 in.)\r\nframe': 1,
#          'H. 86.5 x W. 36 x D. 16 cm (34 1/16 x 14 3/16 x 6 5/16 in.)\r\nweight': 1,
#          '29.8 x 44 cm (11 3/4 x 17 5/16 in.)\r\nframe': 1,
#          '195.3 x 113 cm (76 7/8 x 44 1/2 in.)\r\nframe': 1,
#          '136.5 x 105.2 cm (53 3/4 x 41 7/16 in.)\r\nframed': 1,
#          '38.7 x 38.4 cm (15 1/4 x 15 1/8 in.)\r\nframed': 1,
#          '11.3 x 8 cm (4 7/16 x 3 1/8 in.)\r\nBase': 1,
#          '15.3 x 4.6 cm (6 x 1 13/16 in.)\r\nOriginal base': 1,
#          '17.2 x 6.8 cm (6 3/4 x 2 11/16 in.)\r\nBase': 1,
#          '32.8 x 10.4 cm (12 15/16 x 4 1/8 in.)\r\nBase': 1,
#          '8.2 x 3.8 cm (3 1/4 x 1 1/2 in.)\r\nBase': 1,
#          '25 x 9.1 cm (9 13/16 x 3 9/16 in.)\r\nBase': 1,
#          '21.8 x 7.5 cm (8 9/16 x 2 15/16 in.)\r\nBase': 1,
#          '37 x 11 cm (14 9/16 x 4 5/16 in.)\r\nBase': 1,
#          '21.3 x 9.8 cm (8 3/8 x 3 7/8 in.)\r\nBase': 1,
#          '18.8 x 7.5 cm (7 3/8 x 2 15/16 in.)\r\nBase': 1,
#          '22.3 x 7.7 cm (8 3/4 x 3 1/16 in.)\r\nBase': 1,
#          '23.5 x 7.8 cm (9 1/4 x 3 1/16 in.)\r\nBase': 1,
#          'paper': 744,
#          'vertical ōban': 100,
#          'jar with cover': 3,
#          '122 x 95.5 cm (48 1/16 x 37 5/8 in.)\r\nframed': 1,
#          '39.2 x 28 cm (15 7/16 x 11 in.)\r\nimage': 1,
#          '29.2 x 23 cm (11 1/2 x 9 1/16 in.)\r\nimage': 1,
#          'Album': 1,
#          '75.2 x 45 cm (29 5/8 x 17 11/16 in.)\r\nframe': 1,
#          '53.5 x 60.3 cm (21 1/16 x 23 3/4 in.)\r\nframed': 1,
#          '97.5 x 116.2 cm (38 3/8 x 45 3/4 in.)\r\nframed': 1,
#          'vertical ōban; Paper': 1,
#          'Vertical ōban': 24,
#          'Horizontal ōban': 26,
#          'horizontal ōban': 18,
#          'Vertical chūban': 2,
#          'Chūtanzaku': 1,
#          'painting proper': 263,
#          '41 x 39.8 cm (16 1/8 x 15 11/16 in.)\r\nframe': 1,
#          '40.7 x 50.9 cm (16 x 20 1/16 in.)\r\nArea squared for transfer': 1,
#          '42 x 33.1 cm (16 9/16 x 13 1/16 in.)\r\nBorder drawn around image': 1,
#          '19.4 x 31.8 cm (7 5/8 x 12 1/2 in.)\r\nFramed': 1,
#          '19.4 x 31.8 cm (7 5/8 x 12 1/2 in.)\r\nframed': 1,
#          'image only, sight': 1,
#          'hosoban': 20,
#          'Chūban; Paper': 1,
#          'verticle chuban': 1,
#          'chūban': 2,
#          'H. 16.7 x W. 21.7 x D. 9.9 cm (6 9/16 x 8 9/16 x 3 7/8 in.)\r\nWeight': 1,
#          'each bead, approx.': 1,
#          '29.9 x 22.2 cm (11 3/4 x 8 3/4 in.)\r\nimage': 1,
#          'Vertical ōban diptych': 5,
#          '77.5 x 62.4 cm (30 1/2 x 24 9/16 in.)\r\nframed': 1,
#          '42.9 x 30.2 cm (16 7/8 x 11 7/8 in.)\r\nframed': 1,
#          '39 x 28.4 cm (15 3/8 x 11 3/16 in.)\r\nimage': 1,
#          '40 x 28.3 cm (15 3/4 x 11 1/8 in.)\r\nBorder drawn around image.': 1,
#          '35.6 x 22.4 cm (14 x 8 13/16 in.)\r\nimage within graphite border': 1,
#          '38 x 26.3 cm (14 15/16 x 10 3/8 in.)\r\nimage within graphite border': 1,
#          '32.8 x 25.6 cm (12 15/16 x 10 1/16 in.)\r\nimage within graphite border': 1,
#          '148.3 x 77.8 cm (58 3/8 x 30 5/8 in.)\r\nframed': 1,
#          '148.6 x 77.5 cm (58 1/2 x 30 1/2 in.)\r\nframed': 1,
#          '121.9 × 89.5 cm (48 × 35 1/4 in.)\r\nframed': 1,
#          '125.5 x 105.8 cm (49 7/16 x 41 5/8 in.)\r\nframe': 1,
#          '55.6 x 38 cm (21 7/8 x 14 15/16 in.)\r\nimage': 1,
#          '50 x 31.2 cm (19 11/16 x 12 5/16 in.)\r\nimage': 1,
#          'Hashira-e': 3,
#          'Horizontal chūban': 1,
#          '172.4 x 123.2 cm (67 7/8 x 48 1/2 in.)\r\nframe': 1,
#          '46 x 37.5 cm (18 1/8 x 14 3/4 in.)\r\nframed': 1,
#          '127 x 58.5 cm (50 x 23 1/16 in.)\r\nframed': 1,
#          'image only': 33,
#          '10.3 x 7 cm (4 1/16 x 2 3/4 in.)\r\nBase': 1,
#          '33 x 11.2 cm (13 x 4 7/16 in.)\r\nBase': 1,
#          '12.8 x 10.2 cm (5 1/16 x 4 in.)\r\nBorder drawn around image in graphite.': 1,
#          '23.4 x 15.7 cm (9 3/16 x 6 3/16 in.)\r\nBorder drawn around image.': 1,
#          '23.6 x 15.7 cm (9 5/16 x 6 3/16 in.)\r\nBorder drawn around image': 1,
#          '23.6 x 15.8 cm (9 5/16 x 6 1/4 in.)\r\nBorder drawn around image.': 1,
#          '23.6 x 15.7 cm (9 5/16 x 6 3/16 in.)\r\nBorder drawn around image.': 3,
#          '23.4 x 15.7 cm (9 3/16 x 6 3/16 in.)\r\nimage': 1,
#          '23.2 x 15.7 cm (9 1/8 x 6 3/16 in.)\r\nimage within graphite border': 1,
#          '31.1 x 21.1 cm (12 1/4 x 8 5/16 in.)\r\nimage': 1,
#          'Vertical ōban format': 4,
#          '(print)': 3,
#          '44.7 x 34.3 cm (17 5/8 x 13 1/2 in.)\r\nframed': 1,
#          '121.9 x 61.1 cm (48 x 24 1/16 in.)\r\nframe': 1,
#          '128 x 101.3 cm (50 3/8 x 39 7/8 in.)\r\nframed': 1,
#          '109.86 x 124.46 cm (43 1/4 x 49 in.)\r\nframed': 1,
#          'including strip frame': 1,
#          '36 x 18 x 21 cm (14 3/16 x 7 1/16 x 8 1/4 in.)\r\nwith mount': 1,
#          '30.4 x 19.2 cm (11 15/16 x 7 9/16 in.)\r\nimage': 1,
#          '4.4 x 3.7 x 1.3 cm (1 3/4 x 1 7/16 x 1/2 in.)\r\nwith cardboard frame': 1,
#          'open': 6,
#          '22.7 × 21 cm (8 15/16 × 8 1/4 in.)\r\nimage (irregular)': 1,
#          '47.8 × 30 cm (18 13/16 × 11 13/16 in.)\r\nimage (irregular)': 1,
#          '29.9 x 23.4 cm (11 3/4 x 9 3/16 in.)\r\nBorder drawn around image.': 1,
#          '29.9 x 23.5 cm (11 3/4 x 9 1/4 in.)\r\nBorder drawn around image': 1,
#          '45.8 x 32.7 cm (18 1/16 x 12 7/8 in.)\r\nimage': 1,
#          '32.9 x 45.3 cm (12 15/16 x 17 13/16 in.)\r\nimage': 1,
#          'H. 47.5 x W. 75.8 cm (18 11/16 x 29 13/16 in.)\r\nwith frame': 1,
#          '75.7 x 62.7 cm (29 13/16 x 24 11/16 in.)\r\nframed': 1,
#          '38.5 x 55.8 cm (15 3/16 x 21 15/16 in.)\r\nmount': 1,
#          '20.6 x 18.2 cm (8 1/8 x 7 3/16 in.)\r\nimage': 1,
#          'H. 30.16 x W. 23.5 cm (11 7/8 x 9 1/4 in.)\r\nframed': 1,
#          '30.16 x 23.5 cm (11 7/8 x 9 1/4 in.)\r\nframed': 3,
#          'mat size, painting and calligraphy together': 1,
#          'painting only': 1,
#          '101.6 x 89.2 cm (40 x 35 1/8 in.)\r\nframe': 1,
#          'shrine only': 1,
#          '45.3 x 30.5 cm (17 13/16 x 12 in.)\r\nimage': 1,
#          '65.4 x 93 cm (25 3/4 x 36 5/8 in.)\r\nframed': 1,
#          '74.5 x 41.5 cm (29 5/16 x 16 5/16 in.)\r\nframe': 1,
#          '31.6 x 47.7 cm (12 7/16 x 18 3/4 in.)\r\nmount': 1,
#          '13.7 x 5.4 cm (5 3/8 x 2 1/8 in.)\r\nBase': 1,
#          '37.5 x 12.7 cm (14 3/4 x 5 in.)\r\nBase': 1,
#          '73.7 x 43.2 cm (29 x 17 in.)\r\nframed': 1,
#          '46.4 x 33 cm (18 1/4 x 13 in.)\r\nframed': 1,
#          'H. 95.3 x W. 61.8 cm (37 1/2 x 24 5/16 in.)\r\nFrame': 1,
#          '31.1 x 46 cm (12 1/4 x 18 1/8 in.)\r\nframed': 1,
#          '11.9 x 17.2 cm (4 11/16 x 6 3/4 in.)\r\nmount': 1,
#          '64.8 x 78.5 cm (25 1/2 x 30 7/8 in.)\r\nframe': 1,
#          'frame': 46,
#          '33 x 25.1 cm (13 x 9 7/8 in.)\r\nimage': 1,
#          '19.1 x 33 cm (7 1/2 x 13 in.)\r\nframed': 1,
#          '30.4 x 57 cm (11 15/16 x 22 7/16 in.)\r\nmount': 1,
#          '64.5 x 35.3 x 1.6 cm (25 3/8 x 13 7/8 x 5/8 in.)\r\nwithout border': 1,
#          '64.4 x 34.8 x 1.5 cm (25 3/8 x 13 11/16 x 9/16 in.)\r\nwithout border': 1,
#          'each page': 15,
#          'painting proper (irregular)': 1,
#          '36.5 x 62.2 cm (14 3/8 x 24 1/2 in.)\r\nFramed': 1,
#          '74.3 x 51.1 cm (29 1/4 x 20 1/8 in.)\r\nframed': 1,
#          '23.3 cm (9 3/16 in.)\r\nwith handle': 1,
#          '8.4 x 4.6 cm (3 5/16 x 1 13/16 in.)\r\nmouth': 1,
#          '11.7 x 23 cm (4 5/8 x 9 1/16 in.)\r\nwith handles': 1,
#          '10.6 x 15.7 cm (4 3/16 x 6 3/16 in.)\r\nwith handles': 1,
#          'with handles': 4,
#          'body': 1,
#          '35.56 x 117.48 cm (14 x 46 1/4 in.)\r\nframed': 1,
#          '50.2 × 74.9 cm (19 3/4 × 29 1/2 in.)\r\nframed': 1,
#          '63.5 x 80 cm (25 x 31 1/2 in.)\r\nframed': 1,
#          '87.63 x 158.75 cm (34 1/2 x 62 1/2 in.)\r\nframed': 1,
#          '16.8 x 7.4 cm (6 5/8 x 2 15/16 in.)\r\nBase': 1,
#          '13.3 x 3.6 cm (5 1/4 x 1 7/16 in.)\r\nBase': 1,
#          'Full Height': 1,
#          '17.5 x 6.7 cm (6 7/8 x 2 5/8 in.)\r\nPlinth': 1,
#          '10.4 x 4.5 cm (4 1/8 x 1 3/4 in.)\r\nBase': 1,
#          '20.9 x 13.5 cm (8 1/4 x 5 5/16 in.)\r\nBase': 1,
#          '12 x 4.2 cm (4 3/4 x 1 5/8 in.)\r\nBase': 1,
#          '16 x 5.6 cm (6 5/16 x 2 3/16 in.)\r\nBase': 1,
#          '62.23 x 97.79 cm (24 1/2 x 38 1/2 in.)\r\nframed': 1,
#          '30.5 x 26.5 x 22.6 cm (12 x 10 7/16 x 8 7/8 in.)\r\nwith base': 1,
#          'fragment (max.)': 6,
#          '26.99 x 16.19 cm (10 5/8 x 6 3/8 in.)\r\nframed': 1,
#          '41.6 x 26.7 cm (16 3/8 x 10 1/2 in.)\r\nframed': 1,
#          '15.6 x 4.8 x 4.8 cm (6 1/8 x 1 7/8 x 1 7/8 in.)\r\nbottom': 1,
#          '15.2 x 4.8 x 5.1 cm (6 x 1 7/8 x 2 in.)\r\nbottom': 1,
#          '70.8 x 57.3 cm (27 7/8 x 22 9/16 in.)\r\nframe': 1,
#          '156.8 x 112.7 cm (61 3/4 x 44 3/8 in.)\r\nframed': 1,
#          '53 x 44 x 2.8 cm (20 7/8 x 17 5/16 x 1 1/8 in.)\r\nwith strips of wood': 1,
#          '76.9 x 51 cm (30 1/4 x 20 1/16 in.)\r\nframed': 1,
#          '9.7 x 23.3 cm (3 13/16 x 9 3/16 in.)\r\nmax. with handles': 1,
#          '42 x 24 cm (16 9/16 x 9 7/16 in.)\r\nlower sheet': 1,
#          '116.1 x 95.4 cm (45 11/16 x 37 9/16 in.)\r\nframe': 1,
#          '38.1 x 46 cm (15 x 18 1/8 in.)\r\nframed': 1,
#          '33 x 39.4 cm (13 x 15 1/2 in.)\r\nframed': 1,
#          '35.3 x 50.6 cm (13 7/8 x 19 15/16 in.)\r\nframe': 1,
#          '19.9 x 27 cm (7 13/16 x 10 5/8 in.)\r\nmount': 1,
#          '39.6 x 28.3 cm (15 9/16 x 11 1/8 in.)\r\nmount': 1,
#          '71.1 x 43.2 cm (28 x 17 in.)\r\nframed': 1,
#          '25 x 20.7 cm (9 13/16 x 8 1/8 in.)\r\nmount': 1,
#          '28.1 x 19.6 cm (11 1/16 x 7 11/16 in.)\r\nimage': 1,
#          '28 x 20.2 cm (11 x 7 15/16 in.)\r\nmount': 1,
#          '27.7 x 17.4 cm (10 7/8 x 6 7/8 in.)\r\nmount': 1,
#          '27.2 x 38 cm (10 11/16 x 14 15/16 in.)\r\nmount': 1,
#          '27.6 x 20 cm (10 7/8 x 7 7/8 in.)\r\nmount': 1,
#          '28 x 19 cm (11 x 7 1/2 in.)\r\nGraphite border drawn around image.': 1,
#          '8.6 x 9.1 cm (3 3/8 x 3 9/16 in.)\r\nGraphite border drawn around image': 1,
#          '15 x 14.6 cm (5 7/8 x 5 3/4 in.)\r\nGraphite border drawn around image': 1,
#          '9.5 x 11 cm (3 3/4 x 4 5/16 in.)\r\nGraphite border drawn around image.': 1,
#          '10.3 x 13.3 cm (4 1/16 x 5 1/4 in.)\r\nGraphite border drawn around image.': 1,
#          '21.6 x 31.9 cm (8 1/2 x 12 9/16 in.)\r\nmount': 1,
#          '18.5 x 14.3 cm (7 5/16 x 5 5/8 in.)\r\nGraphite border drawn around image.': 1,
#          '11.1 x 11.3 cm (4 3/8 x 4 7/16 in.)\r\nGraphite border drawn around image.': 1,
#          '42.2 x 50 cm (16 5/8 x 19 11/16 in.)\r\nframe': 1,
#          'Paper (combined width)': 1,
#          'hosoban diptych': 1,
#          'overall for matted pentatych': 1,
#          'Closed': 22,
#          'Each, closed': 2,
#          'closed book': 15,
#          'combined depth of two volumes': 1,
#          'vertical ōban diptych': 1,
#          '56.4 x 45 cm (22 3/16 x 17 11/16 in.)\r\nmount': 1,
#          'with lid on': 1,
#          '55.9 x 45.7 cm (22 x 18 in.)\r\nframed': 4,
#          '61.3 x 43.2 cm (24 1/8 x 17 in.)\r\nframed': 1,
#          '115.89 x 94.62 cm (45 5/8 x 37 1/4 in.)\r\nframed': 1,
#          '108.9 x 74.61 cm (42 7/8 x 29 3/8 in.)\r\nframed': 1,
#          '60.6 x 76.2 cm (23 7/8 x 30 in.)\r\nframed': 1,
#          '17 x 21.2 cm (6 11/16 x 8 3/8 in.)\r\nmount': 1,
#          'closed including cover': 7,
#          'closed (including cover)': 14,
#          'H. 23.5 x W. 16 x D. 17 cm (9 1/4 x 6 5/16 x 6 11/16 in.)\r\nH. including mount and base': 1,
#          '65.1 x 111 cm (25 5/8 x 43 11/16 in.)\r\nframe': 1,
#          '159 x 57.8 cm (62 5/8 x 22 3/4 in.)\r\nframed': 1,
#          'sight, total width of two doors': 1,
#          'sight, one door': 2,
#          'tile face': 1,
#          'maximum, irregular': 1,
#          '30.6 x 24.3 cm (12 1/16 x 9 9/16 in.)\r\nBorder drawn around image.': 1,
#          '28.2 × 18 cm (11 1/8 × 7 1/16 in.)\r\nmount': 2,
#          '28.3 x 18 cm (11 1/8 x 7 1/16 in.)\r\nmount': 1,
#          '58.7 × 71.8 cm (23 1/8 × 28 1/4 in.)\r\nframe': 1,
#          '39.4 x 30.8 cm (15 1/2 x 12 1/8 in.)\r\nframed': 1,
#          '14 x 14.6 cm (5 1/2 x 5 3/4 in.)\r\nframed': 1,
#          '54.6 x 45.1 cm (21 1/2 x 17 3/4 in.)\r\nframed': 1,
#          '92.1 x 71.4 cm (36 1/4 x 28 1/8 in.)\r\nframed': 1,
#          '228 x 148.8 cm (89 3/4 x 58 9/16 in.)\r\nframe': 1,
#          '61.6 x 51.4 cm (24 1/4 x 20 1/4 in.)\r\nframed': 2,
#          '54 x 39.4 cm (21 1/4 x 15 1/2 in.)\r\nframe': 1,
#          '41.3 x 52.7 cm (16 1/4 x 20 3/4 in.)\r\nframed': 1,
#          '120 x 110.5 cm (47 1/4 x 43 1/2 in.)\r\nframed': 1,
#          '66.9 x 50.7 cm (26 5/16 x 19 15/16 in.)\r\nframed': 1,
#          '85.4 x 63.2 cm (33 5/8 x 24 7/8 in.)\r\nframed': 1,
#          '42.6 x 31.5 cm (16 3/4 x 12 3/8 in.)\r\nframe': 1,
#          '45.2 x 35.9 x 7.8 cm (17 13/16 x 14 1/8 x 3 1/16 in.)\r\nframe': 1,
#          '57.2 x 34.9 cm (22 1/2 x 13 3/4 in.)\r\nframed': 1,
#          '31 x 6.7 x 5.3 cm (12 3/16 x 2 5/8 x 2 1/16 in.)\r\nwith mount': 1,
#          '10 x 9.2 x 4.1 cm (3 15/16 x 3 5/8 x 1 5/8 in.)\r\nopen': 1,
#          '16.6 x 13.4 x 2.3 cm (6 9/16 x 5 1/4 x 7/8 in.)\r\nopen': 1,
#          '6.3 x 4.9 x 0.4 cm (2 1/2 x 1 15/16 x 3/16 in.)\r\nsilver cover': 1,
#          'hashira-e': 1,
#          'paper, overall for matted diptych': 1,
#          'vertical ōban triptych': 15,
#          'max.': 171,
#          'H. 71.5 x W. 35.5 cm (28 1/8 x 14 in.)\r\nsight': 1,
#          '42.3 x 65.3 cm (16 5/8 x 25 11/16 in.)\r\nTacking margin surrounds image': 1,
#          'overall length': 1,
#          '15.6 x 6.7 x 1.4 cm (6 1/8 x 2 5/8 x 9/16 in.)\r\nExterior diameter tube': 1,
#          '20.9 x 28 cm (8 1/4 x 11 in.)\r\nframed': 1,
#          '28 x 22.5 x 22.5 cm (11 x 8 7/8 x 8 7/8 in.)\r\nheight with handle': 1,
#          'left section': 1,
#          '45 × 27.2 cm (17 11/16 × 10 11/16 in.)\r\nframed': 1,
#          '93.35 x 74.93 cm (36 3/4 x 29 1/2 in.)\r\nframe': 1,
#          '105.5 x 76.8 cm (41 9/16 x 30 1/4 in.)\r\nframed': 1,
#          'image proper': 9,
#          'approximate dimensions of cut out figure': 1,
#          '21.2 x 18.3 cm (8 3/8 x 7 3/16 in.)\r\nmount': 1,
#          '15.6 x 12.1 cm (6 1/8 x 4 3/4 in.)\r\nmount': 1,
#          'larger fragment': 1,
#          'Phiale body': 1,
#          '16.5 × 15 cm (6 1/2 × 5 7/8 in.)\r\nwidth with handles': 1,
#          'Overall with cover and handles': 1,
#          'Horizontal aiban': 1,
#          'horizontal ōban': 7,
#          'vertical ōban': 6,
#          'Horizontal ōban format': 1,
#          '47.1 x 27.8 cm (18 9/16 x 10 15/16 in.)\r\nmount': 1,
#          '43.5 x 28.5 cm (17 1/8 x 11 1/4 in.)\r\nframed': 1,
#          '6.7 x 16 cm (2 5/8 x 6 5/16 in.)\r\nframed': 1,
#          'arched at top': 1,
#          '28.4 x 17.7 cm (11 3/16 x 6 15/16 in.)\r\nframe': 1,
#          'Vertical ōban; Paper': 2,
#          'ōban': 7,
#          'horizontal \x1eōban': 1,
#          'Veritcal ōban': 1,
#          'Hosoban': 4,
#          'hosoban triptych': 1,
#          'Triptych': 1,
#          'Vertical ōban format triptych': 1,
#          'Vertical ōban triptych': 2,
#          'chūtanzaku': 1,
#          'ōban diptych': 1,
#          'vertical ōban triptych (right panel)': 1,
#          'vertical ōban triptych (center panel)': 1,
#          'vertical ōban triptych (left panel)': 1,
#          'Shikishiban': 53,
#          'chubōn': 1,
#          'shikishi': 1,
#          'shikishiban': 15,
#          'vertical ōban triptych, overall': 3,
#          'vertical ōban triptych, right sheet': 1,
#          'vertical ōban triptych, center sheet': 1,
#          'vertical ōban triptych, left sheet': 1,
#          'Kokonotsugiriban': 1,
#          'yokonagaban': 3,
#          'Kokonotsugiri-ban': 1,
#          'Shikishiban format': 7,
#          'Yatsugiriban format': 1,
#          'vertical koban': 2,
#          'Chūban': 2,
#          'Vertical chūban; Paper': 2,
#          'vertical hosoban': 2,
#          'Paper (fan-shaped format)': 1,
#          'vertical chūban': 5,
#          'ebangire': 1,
#          'paper (unfolded)': 1,
#          'yokonagaban, unfolded': 1,
#          'Three shikishiban': 1,
#          'horizontal chūban': 2,
#          'Vertical koban': 2,
#          '(fragmentary) vertical ōban': 1,
#          '49 x 43.9 cm (19 5/16 x 17 5/16 in.)\r\nframe': 1,
#          '40 × 32.4 cm (15 3/4 × 12 3/4 in.)\r\nframed': 1,
#          '38.4 × 67.3 cm (15 1/8 × 26 1/2 in.)\r\nframed': 1,
#          '157.5 x 96.5 cm (62 x 38 in.)\r\nframed': 1,
#          'Irreg.': 1,
#          '23.6 x 15.7 cm (9 5/16 x 6 3/16 in.)\r\nimage': 1,
#          'H. 47.7 x W. 49.6 x D. 11 cm (18 3/4 x 19 1/2 x 4 5/16 in.)\r\nincluding wooden base': 1,
#          '33.5 x 27.2 cm (13 3/16 x 10 11/16 in.)\r\nframe': 1,
#          '33.6 x 27 cm (13 1/4 x 10 5/8 in.)\r\nframe': 1,
#          '31.43 x 24.45 cm (12 3/8 x 9 5/8 in.)\r\nframed': 1,
#          '47.9 x 34.9 cm (18 7/8 x 13 3/4 in.)\r\nframed': 1,
#          'H. 6.4  W. 12.6  Th. 0.3-0.6': 1,
#          'H. 4.6 x  W. 4.9  x Th.  0.6-07': 1,
#          'H. 12  D. 11.5': 1,
#          'H. 9.4  D 14': 1,
#          'H. 11  D. 11': 1,
#          'H. 7.3, D. 9': 1,
#          'H. 5.3  W. 6.7  Th. 0.6-0.9': 1,
#          'H. 128.9 x W. 83 cm (50 3/4 x 32 11/16 in.)\r\nframed': 1,
#          '55.3 x 68.5 cm (21 3/4 x 26 15/16 in.)\r\nimage': 1,
#          '88.6 x 67 cm (34 7/8 x 26 3/8 in.)\r\nframed': 1,
#          '66.7 x 51.4 cm (26 1/4 x 20 1/4 in.)\r\nframe': 1,
#          '12.7 x 9.5 x 0.6 cm (5 x 3 3/4 x 1/4 in.)\r\nframe': 1,
#          '6.8 diam.  x 0.6 cm depth (2 11/16 x 1/4 in.)\r\nwith loop for hanging': 1,
#          '38.4 x 61.5 cm (15 1/8 x 24 3/16 in.)\r\nframed': 1,
#          '33.6 x 23.9 cm (13 1/4 x 9 7/16 in.)\r\nframed': 1,
#          '26.2 x 37.7 cm (10 5/16 x 14 13/16 in.)\r\nimage': 1,
#          '55.3 × 45.7 cm (21 3/4 × 18 in.)\r\nframed': 1,
#          '35.4 x 25.9 cm (13 15/16 x 10 3/16 in.)\r\nimage': 1,
#          '35.6 x 30.9 cm (14 x 12 3/16 in.)\r\nBorder drawn around image.': 1,
#          '26.35 x 17.8 x 10.2 cm (10 3/8 x 7 x 4 in.)\r\nunspecified': 1,
#          '11.75 x 22.23 x 10.48 cm (4 5/8 x 8 3/4 x 4 1/8 in.)\r\nunspecified': 1,
#          '10.2 x 24.8 x 9.5 cm (4 x 9 3/4 x 3 3/4 in.)\r\nunspecified': 1,
#          '12.07 x 20.96 x 7.62 cm (4 3/4 x 8 1/4 x 3 in.)\r\nunspecified': 1,
#          'teapot dimensions': 1,
#          '12.4 x 25.4 x 9.6 cm (4 7/8 x 10 x 3 3/4 in.)\r\nunspecified': 1,
#          'stand dimensions': 1,
#          '73 x 55.3 cm (28 3/4 x 21 3/4 in.)\r\nframed': 1,
#          '26 x 27.9 cm (10 1/4 x 11 in.)\r\ndiameter at mouth': 1,
#          '24.1 x 26 cm (9 1/2 x 10 1/4 in.)\r\ndiameter at mouth': 1,
#          '30.2 x 23.5 cm (11 7/8 x 9 1/4 in.)\r\ndiameter at top': 1,
#          '19.4 x 22.9 cm (7 5/8 x 9 in.)\r\ndiameter at top': 1,
#          '26 x 46.7 cm (10 1/4 x 18 3/8 in.)\r\ndiameter at mouth': 1,
#          '13.3 x 17.1 cm (5 1/4 x 6 3/4 in.)\r\ndiameter at top': 1,
#          '(reconstructed profile)': 1,
#          'H. 6.2 x W. 8.9 x Th. (body) 0.2 cm (2 7/16 x 3 1/2 x 1/16 in.)\r\nThickness at rim': 1,
#          '27.5 x 41.8 cm (10 13/16 x 16 7/16 in.)\r\nframed': 1,
#          '84.1 x 168.9 cm (33 1/8 x 66 1/2 in.)\r\nframed': 1,
#          '71.1 x 127 cm (28 x 50 in.)\r\nframed': 1,
#          'H. 85.73 x W. 57.15 cm (33 3/4 x 22 1/2 in.)\r\nframed': 1,
#          '33.1 x 43.2 cm (13 1/16 x 17 in.)\r\nimage': 1,
#          '61 x 74.9 cm (24 x 29 1/2 in.)\r\nframed': 1,
#          '33 x 47 cm (13 x 18 1/2 in.)\r\nframe': 1,
#          '32.9 x 24.8 cm (12 15/16 x 9 3/4 in.)\r\nframed': 1,
#          '28.9 x 23.7 cm (11 3/8 x 9 5/16 in.)\r\nframe': 1,
#          '60.3 x 38.1 cm (23 3/4 x 15 in.)\r\nframe': 1,
#          '79.7 x 60.4 cm (31 3/8 x 23 3/4 in.)\r\nframe': 1,
#          '31 x 46.3 cm (12 3/16 x 18 1/4 in.)\r\nframed': 1,
#          '45.4 x 32.7 cm (17 7/8 x 12 7/8 in.)\r\nimage': 1,
#          '5.2 x 3.9 cm (2 1/16 x 1 9/16 in.)\r\nmount': 1,
#          '10.2 x 14.3 cm (4 x 5 5/8 in.)\r\nmount': 1,
#          '14.1 x 19.3 cm (5 9/16 x 7 5/8 in.)\r\nverso image': 1,
#          '81 x 65.1 cm (31 7/8 x 25 5/8 in.)\r\nframed': 2,
#          '92.4 x 52.7 cm (36 3/8 x 20 3/4 in.)\r\nframed': 1,
#          '35.2 x 25.4 cm (13 7/8 x 10 in.)\r\nframed': 4,
#          '17.8 x 12.3 cm (7 x 4 13/16 in.)\r\nframed': 1,
#          '35.6 x 25.1 cm (14 x 9 7/8 in.)\r\nframed': 2,
#          '35.6 x 25.4 cm (14 x 10 in.)\r\nframed': 19,
#          '25.4 x 35.6 cm (10 x 14 in.)\r\nframed': 11,
#          '25.4 x 35.2 cm (10 x 13 7/8 in.)\r\nframed': 5,
#          '41.6 x 34 cm (16 3/8 x 13 3/8 in.)\r\nframed': 1,
#          '17.8 x 12.7 cm (7 x 5 in.)\r\nframed': 1,
#          '39.3 x 21.5 cm (15 1/2 x 8 7/16 in.)\r\nmount': 1,
#          '35.8 x 25.2 cm (14 1/8 x 9 15/16 in.)\r\nframed': 1,
#          '21.6 x 16.8 cm (8 1/2 x 6 5/8 in.)\r\nframed': 1,
#          '24.8 x 35.3 cm (9 3/4 x 13 7/8 in.)\r\nframed': 1,
#          '53.7 x 39.1 cm (21 1/8 x 15 3/8 in.)\r\nframed': 1,
#          '35.88 x 26.04 cm (14 1/8 x 10 1/4 in.)\r\nframed': 1,
#          '37.4 x 29.9 cm (14 3/4 x 11 3/4 in.)\r\nBorder drawn around image.': 1,
#          '28.3 x 38.5 cm (11 1/8 x 15 3/16 in.)\r\nimage': 1,
#          '39.2 x 34.3 cm (15 7/16 x 13 1/2 in.)\r\nimage': 1,
#          '53.7 x 38.2 cm (21 1/8 x 15 1/16 in.)\r\nframed': 1,
#          '35.2 x 25.1 cm (13 7/8 x 9 7/8 in.)\r\nframed': 7,
#          '25.72 x 17.78 cm (10 1/8 x 7 in.)\r\nframed': 1,
#          '54 x 39 cm (21 1/4 x 15 3/8 in.)\r\nframed': 1,
#          '25.7 x 36 cm (10 1/8 x 14 3/16 in.)\r\nmount': 1,
#          '43.2 x 35.6 cm (17 x 14 in.)\r\nframed': 1,
#          '30.5 x 40.6 x 2.2 cm (12 x 16 x 7/8 in.)\r\nframed': 1,
#          '81.3 x 65.1 cm (32 x 25 5/8 in.)\r\nframed': 1,
#          'Total (including hilt)': 2,
#          'each (approx.)': 3,
#          '63.5 x 75.9 cm (25 x 29 7/8 in.)\r\nframed': 1,
#          '69.9 x 82.9 cm (27 1/2 x 32 5/8 in.)\r\nframed': 1,
#          '32.7 x 45.3 cm (12 7/8 x 17 13/16 in.)\r\nimage': 1,
#          '28.7 x 44.3 cm (11 5/16 x 17 7/16 in.)\r\nimage': 1,
#          '36.8 x 24 x 25 cm (14 1/2 x 9 7/16 x 9 13/16 in.)\r\nwith base': 1,
#          '57 x 22.5 x 10.6 cm (22 7/16 x 8 7/8 x 4 3/16 in.)\r\nwood frame': 1,
#          '41.5 x 20.9 cm (16 5/16 x 8 1/4 in.)\r\nInclusive upper and lower attached paper tabs': 1,
#          '21 x 9.3 cm (8 1/4 x 3 11/16 in.)\r\nBase': 1,
#          '29.8 x 23.6 cm (11 3/4 x 9 5/16 in.)\r\nmount': 1,
#          '34.8 x 25.2 cm (13 11/16 x 9 15/16 in.)\r\nBorder drawn around image.': 1,
#          '38.2 x 28 cm (15 1/16 x 11 in.)\r\nimage': 1,
#          '25.7 x 20.6 cm (10 1/8 x 8 1/8 in.)\r\nframed': 1,
#          '25.3 x 35.4 cm (9 15/16 x 13 15/16 in.)\r\nframed': 1,
#          '34.9 x 25.1 cm (13 3/4 x 9 7/8 in.)\r\nframed': 1,
#          '24.9 x 35.3 cm (9 13/16 x 13 7/8 in.)\r\nframed': 1,
#          '35.5 x 25.5 cm (14 x 10 1/16 in.)\r\nframed': 1,
#          '35.3 x 25.4 cm (13 7/8 x 10 in.)\r\nframed': 1,
#          '21.5 x 25.5 cm (8 7/16 x 10 1/16 in.)\r\nmount': 1,
#          '25.1 x 35.2 cm (9 7/8 x 13 7/8 in.)\r\nframed': 1,
#          '21.6 x 16.5 cm (8 1/2 x 6 1/2 in.)\r\nframed': 2,
#          '21.9 x 16.8 cm (8 5/8 x 6 5/8 in.)\r\nframed': 1,
#          '25.5 x 18 cm (10 1/16 x 7 1/16 in.)\r\nmount': 1,
#          '35.6 x 25.5 cm (14 x 10 1/16 in.)\r\nframed': 1,
#          '23 x 30.5 cm (9 1/16 x 12 in.)\r\nframed': 1,
#          '26.7 x 34.9 cm (10 1/2 x 13 3/4 in.)\r\nframed': 1,
#          '26.7 x 40 cm (10 1/2 x 15 3/4 in.)\r\nframed': 1,
#          '26 x 34.9 cm (10 1/4 x 13 3/4 in.)\r\nframed': 1,
#          '26 x 35.9 cm (10 1/4 x 14 1/8 in.)\r\nframed': 1,
#          '35.2 x 24.8 cm (13 7/8 x 9 3/4 in.)\r\nframed': 1,
#          '35.5 x 25.4 cm (14 x 10 in.)\r\nframed': 1,
#          '28.7 x 22.3 cm (11 5/16 x 8 3/4 in.)\r\ntop image': 1,
#          '25.3 x 17.7 cm (9 15/16 x 6 15/16 in.)\r\nframed': 1,
#          '17.9 x 12.8 cm (7 1/16 x 5 1/16 in.)\r\nframed': 1,
#          '24.7 x 34.8 cm (9 3/4 x 13 11/16 in.)\r\nframed': 1,
#          '58.4 x 39.7 cm (23 x 15 5/8 in.)\r\nframed': 2,
#          '20.4 x 12.5 cm (8 1/16 x 4 15/16 in.)\r\nframed': 1,
#          '20.2 x 29 cm (7 15/16 x 11 7/16 in.)\r\nright image': 1,
#          '24.7 x 17 cm (9 3/4 x 6 11/16 in.)\r\nframed': 1,
#          '17.9 x 12.5 cm (7 1/16 x 4 15/16 in.)\r\nframed': 1,
#          '35.3 x 22.6 cm (13 7/8 x 8 7/8 in.)\r\nimage': 1,
#          '35.6 x 25.4 cm (14 x 10 in.)\r\nimage': 1,
#          '28.7 × 14.5 cm (11 5/16 × 5 11/16 in.)\r\nimage': 1,
#          '19.6 x 18.8 cm (7 11/16 x 7 3/8 in.)\r\nGraphite border drawn around image.': 1,
#          '34 x 23.9 cm (13 3/8 x 9 7/16 in.)\r\nframed': 1,
#          '20.5 x 15.3 cm (8 1/16 x 6 in.)\r\nmount': 1,
#          '81.3 x 118.4 cm (32 x 46 5/8 in.)\r\nframed': 1,
#          '35.6 x 25.2 cm (14 x 9 15/16 in.)\r\nlower sheet': 1,
#          '54 x 38.1 cm (21 1/4 x 15 in.)\r\nframed': 1,
#          '35.6 x 25.4 cm (14 x 10 in.)\r\nmount': 1,
#          '33.9 x 22.2 cm (13 3/8 x 8 3/4 in.)\r\nmount': 1,
#          '86.4 x 69.9 cm (34 x 27 1/2 in.)\r\nframed': 1,
#          '28 x 21.8 cm (11 x 8 9/16 in.)\r\nimage': 1,
#          '32 x 21.6 cm (12 5/8 x 8 1/2 in.)\r\neach sheet': 1,
#          '35.5 x 25.4 cm (14 x 10 in.)\r\nphoto': 1,
#          '10.3 x 14.7 cm (4 1/16 x 5 13/16 in.)\r\nmount': 1,
#          '12 x 14.3 cm (4 3/4 x 5 5/8 in.)\r\nmount': 1,
#          '7.8 x 15.4 cm (3 1/16 x 6 1/16 in.)\r\nmount': 1,
#          '10.5 x 16.6 cm (4 1/8 x 6 9/16 in.)\r\nmount': 1,
#          '7.9 x 15.5 cm (3 1/8 x 6 1/8 in.)\r\nmount': 1,
#          '9.1 x 11 cm (3 9/16 x 4 5/16 in.)\r\nmount': 1,
#          '11 x 13.2 cm (4 5/16 x 5 3/16 in.)\r\nmount': 1,
#          '9.2 x 12 cm (3 5/8 x 4 3/4 in.)\r\nmount': 1,
#          '35.7 x 35.7 cm (14 1/16 x 14 1/16 in.)\r\nmount': 1,
#          '54.7 x 71.5 x 3.2 cm (21 9/16 x 28 1/8 x 1 1/4 in.)\r\npage': 1,
#          '64.8 x 52.6 x 5 cm (25 1/2 x 20 11/16 x 1 15/16 in.)\r\npage': 1,
#          '27.8 x 38.1 x 3.8 cm (10 15/16 x 15 x 1 1/2 in.)\r\npage': 1,
#          '73.4 x 56.9 cm (28 7/8 x 22 3/8 in.)\r\neach page': 1,
#          '107 x 81.6 cm (42 1/8 x 32 1/8 in.)\r\nframed': 1,
#          '27.6 x 14.5 x 19 cm (10 7/8 x 5 11/16 x 7 1/2 in.)\r\nwith base': 1,
#          '62.2 x 38 cm (24 1/2 x 14 15/16 in.)\r\nframe': 1,
#          '160 x 160.7 cm (63 x 63 1/4 in.)\r\nframe': 1,
#          'H. 44.7 x W. 30 cm (17 5/8 x 11 13/16 in.)\r\npage': 1,
#          '40.2 x 26.9 cm (15 13/16 x 10 9/16 in.)\r\npage': 1,
#          '25.9 x 9 x 9 cm (10 3/16 x 3 9/16 x 3 9/16 in.)\r\nwith base': 1,
#          '111.5 x 93 cm (43 7/8 x 36 5/8 in.)\r\nframed': 1,
#          '71.3 x 57.3 cm (28 1/16 x 22 9/16 in.)\r\nframed': 1,
#          '92.4 x 78.7 cm (36 3/8 x 31 in.)\r\nframed': 1,
#          '92.4 × 78.7 cm (36 3/8 × 31 in.)\r\nframed': 1,
#          '32 x 37.6 cm (12 5/8 x 14 13/16 in.)\r\nframe': 1,
#          '20.32 cm (8 in.)\r\nframed': 1,
#          '37 × 48 cm (14 9/16 × 18 7/8 in.)\r\nframed': 1,
#          '32 × 44 cm (12 5/8 × 17 5/16 in.)\r\nframed': 1,
#          '61 x 29 cm (24 x 11 7/16 in.)\r\nwith engaged frame': 1,
#          '54.6 x 44.5 cm (21 1/2 x 17 1/2 in.)\r\nframed': 1,
#          '13.9 x 10 cm (5 1/2 x 3 15/16 in.)\r\nframed': 1,
#          'including handle': 1,
#          '145 x 198 cm (57 1/16 x 77 15/16 in.)\r\nframed': 1,
#          '29.2 x 39.4 cm (11 1/2 x 15 1/2 in.)\r\nframed': 1,
#          '16.5 x 2.4 cm (6 1/2 x 15/16 in.)\r\nwith hanging wire': 1,
#          '16.9 x 2.5 cm (6 5/8 x 1 in.)\r\nwith hanging wire': 1,
#          '12.3 × 2.8 cm (4 13/16 × 1 1/8 in.)\r\nframed': 1,
#          '16.3 × 3.2 cm (6 7/16 × 1 1/4 in.)\r\nframed': 1,
#          '15.1 × 3.5 cm (5 15/16 × 1 3/8 in.)\r\nframed': 1,
#          '15 × 3.2 cm (5 7/8 × 1 1/4 in.)\r\nframed': 1,
#          '12 × 2.3 cm (4 3/4 × 7/8 in.)\r\nframed': 1,
#          '9 × 1.7 cm (3 9/16 × 11/16 in.)\r\nframed': 1,
#          '16.9 × 3 cm (6 5/8 × 1 3/16 in.)\r\nframed': 1,
#          '13.6 × 3 cm (5 3/8 × 1 3/16 in.)\r\nframed': 1,
#          '16.1 × 2.9 cm (6 5/16 × 1 1/8 in.)\r\nframed': 1,
#          '14.5 × 2.4 cm (5 11/16 × 15/16 in.)\r\nframed': 1,
#          '15.9 × 3 cm (6 1/4 × 1 3/16 in.)\r\nframed': 1,
#          '16.4 × 3.1 cm (6 7/16 × 1 1/4 in.)\r\n449 g\r\nframed': 1,
#          '16.7 x 2.5 cm (6 9/16 x 1 in.)\r\nwith wire loop for hanging': 1,
#          '18.5 x 12.5 cm (7 5/16 x 4 15/16 in.)\r\nmount': 1,
#          '21.3 x 29.8 cm (8 3/8 x 11 3/4 in.)\r\nframe': 1,
#          '66.1 x 54.6 cm (26 x 21 1/2 in.)\r\nframe': 1,
#          'stretcher': 8,
#          '150.5 x 95.57 cm (59 1/4 x 37 5/8 in.)\r\nframed': 1,
#          '55.4 x 32.5 x 21.1 cm (21 13/16 x 12 13/16 x 8 5/16 in.)\r\nwith mount': 1,
#          '23.3 × 34.9 cm (9 3/16 × 13 3/4 in.)\r\nglazing': 1,
#          '12.1 x 7.9 x 7.9 cm (4 3/4 x 3 1/8 x 3 1/8 in.)\r\nunspecified': 1,
#          'canteen case': 1,
#          '9.84 x 7.62 x 7.3 cm (3 7/8 x 3 x 2 7/8 in.)\r\nunspecified': 1,
#          '80.1 x 129.3 cm (31 9/16 x 50 7/8 in.)\r\nframe': 1,
#          '75.9 x 62.8 cm (29 7/8 x 24 3/4 in.)\r\nframed': 1,
#          '40 x 26.1 cm (15 3/4 x 10 1/4 in.)\r\nframed': 1,
#          '58.1 x 48.26 cm (22 7/8 x 19 in.)\r\nframe': 1,
#          '116.21 x 76.2 cm (45 3/4 x 30 in.)\r\nframed': 1,
#          '68.6 x 116.5 cm (27 x 45 7/8 in.)\r\nframed': 1,
#          '61 x 96 cm (24 x 37 13/16 in.)\r\nframe': 1,
#          '37.2 x 55.6 cm (14 5/8 x 21 7/8 in.)\r\nframed': 1,
#          '34.7 x 49.2 cm (13 11/16 x 19 3/8 in.)\r\nframed': 1,
#          '34.9 x 49.8 cm (13 3/4 x 19 5/8 in.)\r\nframed': 1,
#          'H. 40 x W. 48.3 cm (15 3/4 x 19 in.)\r\nwith mount': 1,
#          'to trimmed paper edge': 1,
#          '43.2 x 36.8 cm (17 x 14 1/2 in.)\r\nframe': 1,
#          'H. 42 x W. 27.4 cm (16 9/16 x 10 13/16 in.)\r\npage': 1,
#          'H. 42.7 x W. 27.5 cm (16 13/16 x 10 13/16 in.)\r\npage': 1,
#          'H. 4.3  W. 5.7  Th.  0.7': 1,
#          'H. 5  W. 4.4  Th.  0.5': 1,
#          '54.8 × 44.2 cm (21 9/16 × 17 3/8 in.)\r\nframe (including wreath at top)': 1,
#          '71.8 x 61.9 cm (28 1/4 x 24 3/8 in.)\r\nframed': 1,
#          '33 x 40.6 cm (13 x 16 in.)\r\nframed': 1,
#          '15.3 x 18.2 cm (6 x 7 3/16 in.)\r\nmount': 1,
#          '53.3 x 72.4 cm (21 x 28 1/2 in.)\r\nframed': 1,
#          '84.5 x 116.8 cm (33 1/4 x 46 in.)\r\nframe': 1,
#          'assembled (approximate)': 1,
#          'including cover': 25,
#          '6.9 x 22 cm (2 11/16 x 8 11/16 in.)\r\nmount': 2,
#          '24.3 x 44.2 cm (9 9/16 x 17 3/8 in.)\r\nmount': 1,
#          '38.4 x 34.2 cm (15 1/8 x 13 7/16 in.)\r\nimage': 1,
#          '44.4 x 13.5 x 12.4 cm (17 1/2 x 5 5/16 x 4 7/8 in.)\r\nwith base': 1,
#          'cap': 1,
#          'H. 10.1 x W. 4.4 x D. 5 cm (4 x 1 3/4 x 1 15/16 in.)\r\nwith stand': 1,
#          '66.7 x 76.4 cm (26 1/4 x 30 1/16 in.)\r\nframed': 1,
#          '77.2 x 49.9 cm (30 3/8 x 19 5/8 in.)\r\nframed': 1,
#          '61 x 51.1 cm (24 x 20 1/8 in.)\r\nframed': 2,
#          '76.3 x 63.6 cm (30 1/16 x 25 1/16 in.)\r\nframed': 2,
#          '109.9 x 104.1 cm (43 1/4 x 41 in.)\r\nframed': 1,
#          '99.9 x 132.4 cm (39 5/16 x 52 1/8 in.)\r\nframe': 1,
#          '24.5 x 33 cm (9 5/8 x 13 in.)\r\nmount, irregular': 1,
#          '25.5 x 35.3 cm (10 1/16 x 13 7/8 in.)\r\nmount': 1,
#          '38.2 x 50.6 cm (15 1/16 x 19 15/16 in.)\r\nimage': 1,
#          '39.2 x 38 cm (15 7/16 x 14 15/16 in.)\r\nBorder drawn around image.': 1,
#          '15.7 x 11.7 cm (6 3/16 x 4 5/8 in.)\r\nmount': 1,
#          '51.8 x 46.7 cm (20 3/8 x 18 3/8 in.)\r\nframed': 1,
#          '45.7 x 55.9 cm (18 x 22 in.)\r\nframed': 1,
#          '49 x 30.9 cm (19 5/16 x 12 3/16 in.)\r\nimage': 1,
#          '76.2 x 49.2 cm (30 x 19 3/8 in.)\r\nframed': 1,
#          '32.7 x 21.8 cm (12 7/8 x 8 9/16 in.)\r\nmount': 1,
#          '30.5 x 40.6 cm (12 x 16 in.)\r\nframed': 1,
#          '52.1 x 41.9 cm (20 1/2 x 16 1/2 in.)\r\nframed': 2,
#          '64.8 x 54.6 cm (25 1/2 x 21 1/2 in.)\r\nframed': 1,
#          '76.5 x 61.9 cm (30 1/8 x 24 3/8 in.)\r\nframed': 1,
#          'overall, with lid on': 4,
#          'overall, with lid': 1,
#          'with lid': 1,
#          'screen only, without stand': 1,
#          'stand only': 3,
#          'overall, jade handle and brush': 1,
#          'album leaf': 6,
#          '24 x 34.2 cm (9 7/16 x 13 7/16 in.)\r\nsheet affixed to album leaf': 6,
#          '24 x 34.2 cm (9 7/16 x 13 7/16 in.)\r\nBorder drawn around image on affixed sheet': 2,
#          '24 x 34.2 cm (9 7/16 x 13 7/16 in.)\r\nBorder drawn around image on sheet affixed.': 1,
#          '24 x 34.2 cm (9 7/16 x 13 7/16 in.)\r\nBorder drawn around image on affixed page': 1,
#          '24 x 34.2 cm (9 7/16 x 13 7/16 in.)\r\nborder around image': 1,
#          '24 x 34.2 cm (9 7/16 x 13 7/16 in.)\r\nimage': 2,
#          '25.1 x 35.5 cm (9 7/8 x 14 in.)\r\nBorder drawn around image.': 9,
#          '31.3 x 6 x 0.4 cm (12 5/16 x 2 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '29 x 5.1 x 0.8 cm (11 7/16 x 2 x 5/16 in.)\r\nunspecified': 1,
#          '37 x 7 x 0.5 cm (14 9/16 x 2 3/4 x 3/16 in.)\r\nunspecified': 1,
#          '24.5 x 7.2 x 0.2 cm (9 5/8 x 2 13/16 x 1/16 in.)\r\nunspecified': 1,
#          '24.4 x 5 x 0.3 cm (9 5/8 x 1 15/16 x 1/8 in.)\r\nunspecified': 1,
#          '43.8 x 6.8 x 0.9 cm (17 1/4 x 2 11/16 x 3/8 in.)\r\nunspecified': 1,
#          '26.2 x 6.7 x 0.5 cm (10 5/16 x 2 5/8 x 3/16 in.)\r\nunspecified': 1,
#          '32.9 x 7.7 x 0.7 cm (12 15/16 x 3 1/16 x 1/4 in.)\r\nunspecified': 1,
#          '34.2 x 8.6 x 0.6 cm (13 7/16 x 3 3/8 x 1/4 in.)\r\nunspecified': 1,
#          '23.5 x 7.5 x 0.5 cm (9 1/4 x 2 15/16 x 3/16 in.)\r\nunspecified': 1,
#          '16.5 x 5.6 x 0.6 cm (6 1/2 x 2 3/16 x 1/4 in.)\r\nunspecified': 1,
#          '25.7 x 10.5 x 0.8 cm (10 1/8 x 4 1/8 x 5/16 in.)\r\nunspecified': 1,
#          '30 x 7.3 x 0.9 cm (11 13/16 x 2 7/8 x 3/8 in.)\r\nunspecified': 1,
#          '29.8 x 8.6 x 0.5 cm (11 3/4 x 3 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '35.2 x 7.4 x 0.6 cm (13 7/8 x 2 15/16 x 1/4 in.)\r\nunspecified': 1,
#          '50 x 9.1 x 0.9 cm (19 11/16 x 3 9/16 x 3/8 in.)\r\nunspecified': 1,
#          '55.6 x 10.4 x  1 cm (21 7/8 x 4 1/8 x 3/8 in.)\r\nunspecified': 1,
#          '59.5 x 10.4 x 0.9 cm (23 7/16 x 4 1/8 x 3/8 in.)\r\nunspecified': 1,
#          '27.8 x 5.6 x 0.6 cm (10 15/16 x 2 3/16 x 1/4 in.)\r\nunspecified': 1,
#          '30 x 6.5 x 0.2 cm (11 13/16 x 2 9/16 x 1/16 in.)\r\nunspecified': 1,
#          '30.5 x 7.5 x 0.5 cm (12 x 2 15/16 x 3/16 in.)\r\nunspecified': 1,
#          '29.4 x 7.1 x 0.3 cm (11 9/16 x 2 13/16 x 1/8 in.)\r\nunspecified': 1,
#          '32 x 6.5 x 0.3 cm (12 5/8 x 2 9/16 x 1/8 in.)\r\nunspecified': 2,
#          '33.2 x 10.4 x 0.8 cm (13 1/16 x 4 1/8 x 5/16 in.)\r\nunspecified': 1,
#          'L. 37.2 x H. 6.2 x Thickness 0.7 cm (14 5/8 x 2 7/16 x 1/4 in.)\r\nunspecified': 1,
#          'H. 32.5 x W. 6 x Thickness 1.4 cm (12 13/16 x 2 3/8 x 9/16 in.)\r\nunspecified': 1,
#          '41 x 25.5 x 5.3 cm (16 1/8 x 10 1/16 x 2 1/16 in.)\r\nwith mount': 1,
#          '41.9 x 31.1 cm (16 1/2 x 12 1/4 in.)\r\nframed': 1,
#          '38.4 x 56.4 cm (15 1/8 x 22 3/16 in.)\r\nFramed': 1,
#          '31 x 21.3 cm (12 3/16 x 8 3/8 in.)\r\nimage': 1,
#          '71.1 x 91.4 cm (28 x 36 in.)\r\nframed': 2,
#          '3.8 x 4.7 x 0.3 cm (1 1/2 x 1 7/8 x 1/8 in.)\r\nunspecified': 2,
#          '6 x 2.4 x 0.6 cm (2 3/8 x 15/16 x 1/4 in.)\r\nunspecified': 1,
#          '6.1 x 2 x 0.5 cm (2 3/8 x 13/16 x 3/16 in.)\r\nunspecified': 1,
#          '7.2 x 1.3 x 0.4 cm (2 13/16 x 1/2 x 3/16 in.)\r\nunspecified': 1,
#          '4.4 x 2.7 x 0.3 cm (1 3/4 x 1 1/16 x 1/8 in.)\r\nunspecified': 1,
#          '7 x 2.7 x 0.3 cm (2 3/4 x 1 1/16 x 1/8 in.)\r\nunspecified': 1,
#          '8.7 x 7 x 0.5 cm (3 7/16 x 2 3/4 x 3/16 in.)\r\nunspecified': 1,
#          '9.2 x 2.5 x 2.2 cm (3 5/8 x 1 x 7/8 in.)\r\nunspecified': 1,
#          '11.7 x 2.8 x 2.5 cm (4 5/8 x 1 1/8 x 1 in.)\r\nunspecified': 1,
#          '10.9 x 2.5 x 2.6 cm (4 5/16 x 1 x 1 in.)\r\nunspecified': 1,
#          '10.6 x 2.5 x 2.3 cm (4 3/16 x 1 x 7/8 in.)\r\nunspecified': 1,
#          '9.3 x 2.4 x 2.3 cm (3 11/16 x 15/16 x 7/8 in.)\r\nunspecified': 1,
#          '11.6 x 2.8 x 2.6 cm (4 9/16 x 1 1/8 x 1 in.)\r\nunspecified': 1,
#          '11.5 x 3 x 2.7 cm (4 1/2 x 1 3/16 x 1 1/16 in.)\r\nunspecified': 1,
#          '9.3 x 2.5 x 2.1 cm (3 11/16 x 1 x 13/16 in.)\r\nunspecified': 1,
#          '9.3 x 2.5 x 2.2 cm (3 11/16 x 1 x 7/8 in.)\r\nunspecified': 1,
#          '11.7 x 3 x 2.8 cm (4 5/8 x 1 3/16 x 1 1/8 in.)\r\nunspecified': 1,
#          '11.8 x 3 x 2.7 cm (4 5/8 x 1 3/16 x 1 1/16 in.)\r\nunspecified': 1,
#          '1.3 x 3.6 x 1.8 cm (1/2 x 1 7/16 x 11/16 in.)\r\nunspecified': 1,
#          '2.8 x 1.4 x 0.5 cm (1 1/8 x 9/16 x 3/16 in.)\r\nunspecified': 1,
#          '3.9 x 3.1 x 1.2 cm (1 9/16 x 1 1/4 x 1/2 in.)\r\nunspecified': 1,
#          '2.5 x 4.6 x 3.5 cm (1 x 1 13/16 x 1 3/8 in.)\r\nunspecified': 1,
#          '4.2 x 2.3 x 1.5 cm (1 5/8 x 7/8 x 9/16 in.)\r\nunspecified': 1,
#          '5.4 x 3.2 x 0.8 cm (2 1/8 x 1 1/4 x 5/16 in.)\r\nunspecified': 1,
#          '5.4 x 2.9 x 0.7 cm (2 1/8 x 1 1/8 x 1/4 in.)\r\nunspecified': 1,
#          '6 x 2.7 x 1 cm (2 3/8 x 1 1/16 x 3/8 in.)\r\nunspecified': 1,
#          '4.7 x 2.8 x 1.2 cm (1 7/8 x 1 1/8 x 1/2 in.)\r\nunspecified': 1,
#          '2.1 x 1.3 x 0.8 cm (13/16 x 1/2 x 5/16 in.)\r\nunspecified': 1,
#          '4 x 2.4 x 0.3 cm (1 9/16 x 15/16 x 1/8 in.)\r\nunspecified': 1,
#          '2 x 1.4 x 1.1 cm (13/16 x 9/16 x 7/16 in.)\r\nunspecified': 1,
#          '4.2 x 2.4 x 0.4 cm (1 5/8 x 15/16 x 3/16 in.)\r\nunspecified': 1,
#          '3.8 x 2.4 x 0.4 cm (1 1/2 x 15/16 x 3/16 in.)\r\nunspecified': 1,
#          '3.6 x 2.3 x 0.7 cm (1 7/16 x 7/8 x 1/4 in.)\r\nunspecified': 1,
#          '2 x 6.4 x 0.3 cm (13/16 x 2 1/2 x 1/8 in.)\r\nunspecified': 1,
#          '8 x 3.5 x 0.4 cm (3 1/8 x 1 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '6.2 x 1.7 x 0.8 cm (2 7/16 x 11/16 x 5/16 in.)\r\nunspecified': 1,
#          '10.1 x 1.9 x 0.6 cm (4 x 3/4 x 1/4 in.)\r\nunspecified': 1,
#          '3.9 x 2.5 x 0.4 cm (1 9/16 x 1 x 3/16 in.)\r\nunspecified': 2,
#          'H. 3 x W. 2.3 cm (1 3/16 x 7/8 in.)\r\nunspecified': 1,
#          '6 x 0.7 x 0.7 cm (2 3/8 x 1/4 x 1/4 in.)\r\nunspecified': 1,
#          '5.9 x 0.6 x 0.9 cm (2 5/16 x 1/4 x 3/8 in.)\r\nunspecified': 1,
#          '1 x 3.6 x 0.6 cm (3/8 x 1 7/16 x 1/4 in.)\r\nunspecified': 1,
#          '9.1 x 3.8 x 2.7 cm (3 9/16 x 1 1/2 x 1 1/16 in.)\r\nunspecified': 1,
#          '4.6 x 1.9 x 0.5 cm (1 13/16 x 3/4 x 3/16 in.)\r\nunspecified': 1,
#          '7.8 x 2.3 x 2 cm (3 1/16 x 7/8 x 13/16 in.)\r\nunspecified': 1,
#          '5.3 x 2.7 x 0.8 cm (2 1/16 x 1 1/16 x 5/16 in.)\r\nunspecified': 1,
#          '3.3 x 2.8 cm (1 5/16 x 1 1/8 in.)\r\nunspecified': 1,
#          'L. 4.1 x W. 1.3 cm (1 5/8 x 1/2 in.)\r\nunspecified': 1,
#          '6.7 x 2 x 0.9 cm (2 5/8 x 13/16 x 3/8 in.)\r\nunspecified': 1,
#          '6.8 x 1.9 x 1 cm (2 11/16 x 3/4 x 3/8 in.)\r\nunspecified': 1,
#          '4.3 x 1.9 x 0.4 cm (1 11/16 x 3/4 x 3/16 in.)\r\nunspecified': 1,
#          '3.6 x 2.7 x 0.3 cm (1 7/16 x 1 1/16 x 1/8 in.)\r\nunspecified': 1,
#          '4.7 x 2.2 x 0.5 cm (1 7/8 x 7/8 x 3/16 in.)\r\nunspecified': 1,
#          '4.8 x 2.2 x 0.4 cm (1 7/8 x 7/8 x 3/16 in.)\r\nunspecified': 1,
#          '3.3 x 0.4 cm (1 5/16 x 3/16 in.)\r\nunspecified': 1,
#          '4 x 2.8 x 0.2 cm (1 9/16 x 1 1/8 x 1/16 in.)\r\nunspecified': 1,
#          '111.4 x 88.6 cm (43 7/8 x 34 7/8 in.)\r\nframed': 1,
#          '89.2 x 74.9 cm (35 1/8 x 29 1/2 in.)\r\nframe': 1,
#          '92.1 x 125.7 cm (36 1/4 x 49 1/2 in.)\r\nframed': 1,
#          '103.2 × 62.7 cm (40 5/8 × 24 11/16 in.)\r\nframed': 1,
#          '46 × 38.4 cm (18 1/8 × 15 1/8 in.)\r\nframed': 1,
#          '51.8 x 61 cm (20 3/8 x 24 in.)\r\nframed': 1,
#          '35.6 x 61 cm (14 x 24 in.)\r\nframed': 1,
#          '8.2 x 2.2 x 0.9 cm (3 1/4 x 7/8 x 3/8 in.)\r\nunspecified': 1,
#          '7.6 x 7 x 1.1 cm (3 x 2 3/4 x 7/16 in.)\r\nunspecified': 1,
#          '6.6 x 2 x 0.5 cm (2 5/8 x 13/16 x 3/16 in.)\r\nunspecified': 1,
#          '6.6 x 2 x 0.6 cm (2 5/8 x 13/16 x 1/4 in.)\r\nunspecified': 1,
#          '14.4 x 1.5 x 0.3 cm (5 11/16 x 9/16 x 1/8 in.)\r\nunspecified': 1,
#          '0.9 x 0.9 x 1 cm (3/8 x 3/8 x 3/8 in.)\r\nunspecified': 1,
#          '3.1 x 6.6 x 0.4 cm (1 1/4 x 2 5/8 x 3/16 in.)\r\nunspecified': 1,
#          '3.2 x 6.5 x 0.4 cm (1 1/4 x 2 9/16 x 3/16 in.)\r\nunspecified': 1,
#          '0.2 x 4.4 cm (1/16 x 1 3/4 in.)\r\nunspecified': 1,
#          '4.3 x 3 x 0.5 cm (1 11/16 x 1 3/16 x 3/16 in.)\r\nunspecified': 1,
#          '4.1 x 2.9 x 0.5 cm (1 5/8 x 1 1/8 x 3/16 in.)\r\nunspecified': 1,
#          '4.5 x 1 x 0.4 cm (1 3/4 x 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '7.4 x 1.2 x 0.6 cm (2 15/16 x 1/2 x 1/4 in.)\r\nunspecified': 1,
#          '2.4 x 4.7 x 0.5 cm (15/16 x 1 7/8 x 3/16 in.)\r\nunspecified': 1,
#          '0.4 x 1.5 x 9.4 cm (3/16 x 9/16 x 3 11/16 in.)\r\nunspecified': 1,
#          'each': 56,
#          '5.5 x 3.1 x 0.7 cm (2 3/16 x 1 1/4 x 1/4 in.)\r\nunspecified': 1,
#          '3.7 x 6.1 x 0.5 cm (1 7/16 x 2 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '4.3 x 0.4 x 7 cm (1 11/16 x 3/16 x 2 3/4 in.)\r\nunspecified': 1,
#          '7 x 2.3 x 1.9 cm (2 3/4 x 7/8 x 3/4 in.)\r\nunspecified': 1,
#          '6.6 x 4 x 0.3 cm (2 5/8 x 1 9/16 x 1/8 in.)\r\nunspecified': 1,
#          '1 x 5.2 x 0.5 cm (3/8 x 2 1/16 x 3/16 in.)\r\nunspecified': 1,
#          '4 x 3.8 x 0.4 cm (1 9/16 x 1 1/2 x 3/16 in.)\r\nunspecified': 1,
#          '4.3 x 0.6 x 6.3 cm (1 11/16 x 1/4 x 2 1/2 in.)\r\nunspecified': 1,
#          '11.7 x 1.9 x 0.7 cm (4 5/8 x 3/4 x 1/4 in.)\r\nunspecified': 1,
#          '6.1 x 4.1 x 1.7 cm (2 3/8 x 1 5/8 x 11/16 in.)\r\nunspecified': 1,
#          '8 x 3 x 2.5 cm (3 1/8 x 1 3/16 x 1 in.)\r\nunspecified': 1,
#          '14 x 22 x 0.5 cm (5 1/2 x 8 11/16 x 3/16 in.)\r\nunspecified': 1,
#          '2.3 x 1.2 x 1.6 cm (7/8 x 1/2 x 5/8 in.)\r\nunspecified': 1,
#          '4.3 x 4.5 x 0.5 cm (1 11/16 x 1 3/4 x 3/16 in.)\r\nunspecified': 1,
#          '4.2 x 2 x 0.4 cm (1 5/8 x 13/16 x 3/16 in.)\r\nunspecified': 1,
#          '1.8 x 3.3 x 0.4 cm (11/16 x 1 5/16 x 3/16 in.)\r\nunspecified': 1,
#          '1.7 x 4 x 0.3 cm (11/16 x 1 9/16 x 1/8 in.)\r\nunspecified': 1,
#          '3.1 x 2.2 x 0.4 cm (1 1/4 x 7/8 x 3/16 in.)\r\nunspecified': 1,
#          '1.7 x 2.8 x 0.5 cm (11/16 x 1 1/8 x 3/16 in.)\r\nunspecified': 1,
#          '8 x 4 x 0.6 cm (3 1/8 x 1 9/16 x 1/4 in.)\r\nunspecified': 1,
#          '7 x 1.7 x 0.4 cm (2 3/4 x 11/16 x 3/16 in.)\r\nunspecified': 1,
#          '3.4 x 5.8 x 0.4 cm (1 5/16 x 2 5/16 x 3/16 in.)\r\nunspecified': 1,
#          '2.3 x 3.5 x 0.5 cm (7/8 x 1 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '52.6 x 8.8 x 0.2 cm (20 11/16 x 3 7/16 x 1/16 in.)\r\nunspecified': 1,
#          '44.6 x 8 x 0.2 cm (17 9/16 x 3 1/8 x 1/16 in.)\r\nunspecified': 1,
#          '39 x 8 x 0.8 cm (15 3/8 x 3 1/8 x 5/16 in.)\r\nunspecified': 1,
#          '40.5 x 7.5 x 0.6 cm (15 15/16 x 2 15/16 x 1/4 in.)\r\nunspecified': 1,
#          '26.5 x 5.5 x 0.6 cm (10 7/16 x 2 3/16 x 1/4 in.)\r\nunspecified': 1,
#          '34.2 x 5 x 0.7 cm (13 7/16 x 1 15/16 x 1/4 in.)\r\nweight': 1,
#          '36.5 x 7.3 x 0.5 cm (14 3/8 x 2 7/8 x 3/16 in.)\r\nunspecified': 1,
#          '41.8 x 10.4 x 1 cm (16 7/16 x 4 1/8 x 3/8 in.)\r\nunspecified': 1,
#          '29.8 x 8.4 x 0.5 cm (11 3/4 x 3 5/16 x 3/16 in.)\r\nunspecified': 1,
#          '39.8 x 7.5 x 0.5 cm (15 11/16 x 2 15/16 x 3/16 in.)\r\nunspecified': 1,
#          '29.6 x 8.3 x 1 cm (11 5/8 x 3 1/4 x 3/8 in.)\r\nunspecified': 1,
#          '30.7 x 7.6 x 1.1 cm (12 1/16 x 3 x 7/16 in.)\r\nunspecified': 1,
#          '26.2 x 8.2 x 0.8 cm (10 5/16 x 3 1/4 x 5/16 in.)\r\nunspecified': 1,
#          '26 x 7 x 0.7 cm (10 1/4 x 2 3/4 x 1/4 in.)\r\nunspecified': 1,
#          '21.2 x 5.3 x 0.4 cm (8 3/8 x 2 1/16 x 3/16 in.)\r\nunspecified': 1,
#          '21.2 x 6.2 x 0.3 cm (8 3/8 x 2 7/16 x 1/8 in.)\r\nunspecified': 1,
#          '22.9 x 6 x 0.6 cm (9 x 2 3/8 x 1/4 in.)\r\nunspecified': 1,
#          '18.1 x 4.9 x 0.2 cm (7 1/8 x 1 15/16 x 1/16 in.)\r\nunspecified': 1,
#          '18.8 x 4.7 x 0.3 cm (7 3/8 x 1 7/8 x 1/8 in.)\r\nunspecified': 1,
#          '21.3 x 4.3 x 0.5 cm (8 3/8 x 1 11/16 x 3/16 in.)\r\nunspecified': 1,
#          '24 x 6.3 x 0.8 cm (9 7/16 x 2 1/2 x 5/16 in.)\r\nunspecified': 1,
#          '24.3 x 5 x 0.3 cm (9 9/16 x 1 15/16 x 1/8 in.)\r\nunspecified': 1,
#          '21.4 x 4 x 0.5 cm (8 7/16 x 1 9/16 x 3/16 in.)\r\nunspecified': 1,
#          '19.5 x 6 x 0.4 cm (7 11/16 x 2 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '21.7 x 6.2 x 0.6 cm (8 9/16 x 2 7/16 x 1/4 in.)\r\nunspecified': 1,
#          '16.3 x 4.6 x 0.2 cm (6 7/16 x 1 13/16 x 1/16 in.)\r\nunspecified': 1,
#          '14.5 x 5.5 x 0.7 cm (5 11/16 x 2 3/16 x 1/4 in.)\r\nunspecified': 1,
#          '16 x 8.6 x 0.5 cm (6 5/16 x 3 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '12.7 x 9.5 x 0.4 cm (5 x 3 3/4 x 3/16 in.)\r\nunspecified': 1,
#          '11.7 x 8.8 x 0.7 cm (4 5/8 x 3 7/16 x 1/4 in.)\r\nunspecified': 1,
#          '17.7 x 6.3 x 0.4 cm (6 15/16 x 2 1/2 x 3/16 in.)\r\nunspecified': 1,
#          '8.5 x 6.5 x 0.7 cm (3 3/8 x 2 9/16 x 1/4 in.)\r\nunspecified': 1,
#          '9.3 x 9.4 x 0.4 cm (3 11/16 x 3 11/16 x 3/16 in.)\r\nunspecified': 1,
#          '21.8 x 8.3 x 0.3 cm (8 9/16 x 3 1/4 x 1/8 in.)\r\nunspecified': 1,
#          '17.7 x 13.4 x 0.4 cm (6 15/16 x 5 1/4 x 3/16 in.)\r\nunspecified': 1,
#          '16.1 x 13.3 x 0.5 cm (6 5/16 x 5 1/4 x 3/16 in.)\r\nunspecified': 1,
#          '15.3 x 15.1 x 0.6 cm (6 x 5 15/16 x 1/4 in.)\r\nunspecified': 1,
#          '27 x 14.7 x 0.8 cm (10 5/8 x 5 13/16 x 5/16 in.)\r\nunspecified': 1,
#          '10.8 x 3.3 x 0.7 cm (4 1/4 x 1 5/16 x 1/4 in.)\r\nunspecified': 1,
#          '15.3 x 3.9 x 0.4 cm (6 x 1 9/16 x 3/16 in.)\r\nunspecified': 1,
#          '11 x 2 x 0.8 cm (4 5/16 x 13/16 x 5/16 in.)\r\nunspecified': 1,
#          '29.5 x 10.2 x 3.3 cm (11 5/8 x 4 x 1 5/16 in.)\r\nunspecified': 1,
#          '33 x 13.8 x 0.4 cm (13 x 5 7/16 x 3/16 in.)\r\nunspecified': 1,
#          '28.5 x 7.7 x 0.4 cm (11 1/4 x 3 1/16 x 3/16 in.)\r\nunspecified': 1,
#          '15.5 x 7 x 1.5 cm (6 1/8 x 2 3/4 x 9/16 in.)\r\nunspecified': 1,
#          '11 x 6.5 x 1.4 cm (4 5/16 x 2 9/16 x 9/16 in.)\r\nunspecified': 1,
#          '6.2 x 1.4 x 0.6 cm (2 7/16 x 9/16 x 1/4 in.)\r\nunspecified': 1,
#          '5 x 2.4 x 0.4 cm (1 15/16 x 15/16 x 3/16 in.)\r\nunspecified': 2,
#          '30.5 x 6.3 x 7.1 cm (12 x 2 1/2 x 2 13/16 in.)\r\nunspecified': 1,
#          '30.2 x 6.5 x 7.5 cm (11 7/8 x 2 9/16 x 2 15/16 in.)\r\nunspecified': 1,
#          '26 x 6.4 x 7.3 cm (10 1/4 x 2 1/2 x 2 7/8 in.)\r\nunspecified': 1,
#          '4.1 x 3.1 x 0.1 cm (1 5/8 x 1 1/4 x 1/16 in.)\r\nunspecified': 1,
#          '4.1 x 3.3 x 0.2 cm (1 5/8 x 1 5/16 x 1/16 in.)\r\nunspecified': 1,
#          '5.5 x 1.6 x 0.6 cm (2 3/16 x 5/8 x 1/4 in.)\r\nunspecified': 1,
#          '10.3 x 2.2 x 0.4 cm (4 1/16 x 7/8 x 3/16 in.)\r\nunspecified': 1,
#          '8.1 x 2 x 0.4 cm (3 3/16 x 13/16 x 3/16 in.)\r\nunspecified': 1,
#          '5.8 x 2.8 x 0.5 cm (2 5/16 x 1 1/8 x 3/16 in.)\r\nunspecified': 1,
#          '7.6 x 1.7 x 0.3 cm (3 x 11/16 x 1/8 in.)\r\nunspecified': 1,
#          '2 x 19.6 x 0.5 cm (13/16 x 7 11/16 x 3/16 in.)\r\nunspecified': 1,
#          '8.8 x 2.4 x 0.4 cm (3 7/16 x 15/16 x 3/16 in.)\r\nunspecified': 1,
#          '10.5 x 2 x 0.3 cm (4 1/8 x 13/16 x 1/8 in.)\r\nunspecified': 1,
#          '10.3 x 2.7 x 0.3 cm (4 1/16 x 1 1/16 x 1/8 in.)\r\nunspecified': 1,
#          'W. 6.8 x Thickness 0.3 cm (2 11/16 x 1/8 in.)\r\nunspecified': 1,
#          '7.5 x 1.6 x 0.4 cm (2 15/16 x 5/8 x 3/16 in.)\r\nunspecified': 1,
#          '2.6 x 3.3 x 0.3 cm (1 x 1 5/16 x 1/8 in.)\r\nunspecified': 1,
#          '2.6 x 3.5 x 0.3 cm (1 x 1 3/8 x 1/8 in.)\r\nunspecified': 1,
#          '2.2 x 8.6 x 0.5 cm (7/8 x 3 3/8 x 3/16 in.)\r\nunspecified': 1,
#          '2.7 x 5.5 x 0.2 cm (1 1/16 x 2 3/16 x 1/16 in.)\r\nunspecified': 1,
#          '0.3 x 3.8 cm (1/8 x 1 1/2 in.)\r\nunspecified': 2,
#          '1.5 x 3.4 x 0.5 cm (9/16 x 1 5/16 x 3/16 in.)\r\nunspecified': 1,
#          '3.6 x 4.1 x 0.2 cm (1 7/16 x 1 5/8 x 1/16 in.)\r\nunspecified': 1,
#          '3.3 x 4.1 x 0.2 cm (1 5/16 x 1 5/8 x 1/16 in.)\r\nunspecified': 1,
#          '4.3 x 3.2 x 0.5 cm (1 11/16 x 1 1/4 x 3/16 in.)\r\nunspecified': 1,
#          '4.6 x 2.7 x 0.6 cm (1 13/16 x 1 1/16 x 1/4 in.)\r\nunspecified': 1,
#          '12 x 0.4 cm (4 3/4 x 3/16 in.)\r\nunspecified': 1,
#          '8.1 x 2.5 x 0.2 cm (3 3/16 x 1 x 1/16 in.)\r\nunspecified': 1,
#          '4.1 x 2.6 x 1 cm (1 5/8 x 1 x 3/8 in.)\r\nunspecified': 1,
#          '2.6 x 1.1 x 1.1 cm (1 x 7/16 x 7/16 in.)\r\nunspecified': 1,
#          'L.13 x W. 1.6 cm (5 1/8 x 5/8 in.)\r\nunspecified': 1,
#          'L. 11.8 x W. 2.2 cm (4 5/8 x 7/8 in.)\r\nunspecified': 1,
#          'L. 12.5 x W. 3.8 cm (4 15/16 x 1 1/2 in.)\r\nunspecified': 1,
#          '8.6 x 2.2 x 2.4 cm (3 3/8 x 7/8 x 15/16 in.)\r\nunspecified': 2,
#          'L. 7.3 x W. 2.7 cm (2 7/8 x 1 1/16 in.)\r\nunspecified': 1,
#          'H. 2.3 x Diam. 1.8 cm (7/8 x 11/16 in.)\r\nunspecified': 2,
#          '2.9 x 4 x 1.4 cm (1 1/8 x 1 9/16 x 9/16 in.)\r\nunspecified': 1,
#          '2.8 x 4.1 x 1.5 cm (1 1/8 x 1 5/8 x 9/16 in.)\r\nunspecified': 1,
#          'H. 1.7 x W. 4.2 cm (11/16 x 1 5/8 in.)\r\nunspecified': 1,
#          '5.8 x 3.6 x 0.3 cm (2 5/16 x 1 7/16 x 1/8 in.)\r\nunspecified': 1,
#          '5.2 x 3.1 x 0.3 cm (2 1/16 x 1 1/4 x 1/8 in.)\r\nunspecified': 1,
#          ...})

# %% [markdown]
# Okay, looks like this part of the data is super messy. Let's try to consolidate it a bit.
